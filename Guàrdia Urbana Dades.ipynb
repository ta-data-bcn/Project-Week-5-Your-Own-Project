# %%
import pandas as pd

# %%
persones = pd.read_csv('./2018_accidents_persones_gu_bcn_.csv')
persones.head()
causes = pd.read_csv('./2018_accidents_causes_.csv')
gestionats = pd.read_csv('./2018_accidents_gu_bcn.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-80e46b8543c4> in <module>
# ----> 1 persones = pd.read_csv('./2018_accidents_persones_gu_bcn_.csv')
#       2 persones.head()
#       3 causes = pd.read_csv('./2018_accidents_causes_.csv')
#       4 gestionats = pd.read_csv('./2018_accidents_gu_bcn.csv')
#
# ...

# %%
codi = accidents.loc[accidents['Coordenada_UTM_Y'] == ]
codi
# Out:
#         Codi_expedient  Codi_districte Nom_districte  Codi_barri Nom_barri  \
# 0      2018S007344                   1  Ciutat Vella           1  el Raval
# 14917  2018S009862                   1  Ciutat Vella           1  el Raval
#
#        Codi_carrer                                         Nom_carrer  \
# 0           269108  Rambla                                        ...
# 14917       269108  Rambla                                        ...
#
#       Num_postal  Descripcio_dia_setmana Dia_setmana  ...  \
# 0               1               Diumenge          Dg  ...
# 14917           5               Dimecres          Dc  ...
#
#       Descripcio_tipus_vehicle  Descripcio_model  Descripcio_marca  \
# 0                      Turisme           CORDOBA              SEAT
# 14917                  Turisme             CORSA              OPEL
#
#       Descripcio_color  Descripcio_carnet  Antiguitat_carnet Coordenada_UTM_X  \
# ...

# %%
accidents.head()
# Out:
#     Codi_expedient  Codi_districte Nom_districte  Codi_barri       Nom_barri  \
# 0  2018S007344                   1  Ciutat Vella           1        el Raval
# 1  2018S009617                   1  Ciutat Vella           1        el Raval
# 2  2018S008382                   1  Ciutat Vella           2  el Barri Gòtic
# 3  2018S002684                   1  Ciutat Vella           2  el Barri Gòtic
# 4  2018S004886                   1  Ciutat Vella           2  el Barri Gòtic
#
#    Codi_carrer                                         Nom_carrer Num_postal   \
# 0       269108  Rambla                                        ...           1
# 1       701265  B-10 (Besòs)                                  ...  K110
# 2        34308  Ferran                                        ...           2
# 3        55909  Call                                          ...          21
# 4        82901  Colom                                         ...          25
#
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19079 entries, 0 to 19078
# Data columns (total 28 columns):
# Codi_expedient              19079 non-null object
# Codi_districte              19079 non-null int64
# Nom_districte               19079 non-null object
# Codi_barri                  19079 non-null int64
# Nom_barri                   19079 non-null object
# Codi_carrer                 19079 non-null int64
# Nom_carrer                  19079 non-null object
# Num_postal                  5144 non-null object
# Descripcio_dia_setmana      19079 non-null object
# Dia_setmana                 19079 non-null object
# Descripcio_tipus_dia        19079 non-null object
# Any                         19079 non-null int64
# Mes_any                     19079 non-null int64
# Nom_mes                     19079 non-null object
# Dia_mes                     19079 non-null int64
# Hora_dia                    19079 non-null int64
# Descripcio_torn             19079 non-null object
# ...

# %%
causes.head()
# Out:
#   Numero_expedient  Codi_districte        Nom_districte  Codi_barri  \
# 0  2018S009653                   5  Sarrià-Sant Gervasi          22
# 1  2018S000730                   5  Sarrià-Sant Gervasi          22
# 2  2018S009722                   5  Sarrià-Sant Gervasi          22
# 3  2018S004776                   5  Sarrià-Sant Gervasi          22
# 4  2018S007190                   5  Sarrià-Sant Gervasi          22
#
#                                Nom_barri  Codi_carrer  \
# 0  Vallvidrera, el Tibidabo i les Planes       700059
# 1  Vallvidrera, el Tibidabo i les Planes        73139
# 2  Vallvidrera, el Tibidabo i les Planes       700059
# 3  Vallvidrera, el Tibidabo i les Planes       700059
# 4  Vallvidrera, el Tibidabo i les Planes       700059
#
#                                           Nom_carrer Num_postal   \
# 0  Vallvidrera a les Planes                      ...  102-112
# 1  Vimetera / Gespa                              ...         NaN
# ...

# %%
gestionats.head()
# Out:
#   Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0  2018S000150                   3  Sants-Montjuïc          12
# 1  2018S000761                   3  Sants-Montjuïc          11
# 2  2018S005151                   3  Sants-Montjuïc          12
# 3  2018S000933                   3  Sants-Montjuïc          12
# 4  2018S006926                   3  Sants-Montjuïc          12
#
#                     Nom_barri  Codi_carrer  \
# 0  la Marina del Prat Vermell       701819
# 1                el Poble-sec       234001
# 2  la Marina del Prat Vermell       370531
# 3  la Marina del Prat Vermell       701819
# 4  la Marina del Prat Vermell       370203
#
#                                           Nom_carrer Num_postal   \
# 0  Número 3 Zona Franca / E Zona Franca          ...  69-75
# 1  Olímpic                                       ...  5-7
# 2  A Zona Franca / Número 6 Zona Franca          ...         NaN
# 3  Número 3 Zona Franca / E                      ...  69-75
# ...

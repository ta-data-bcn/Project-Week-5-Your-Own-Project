# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import re
sns.set()

# %%
url = "http://insideairbnb.com/get-the-data.html"
response = get(url)

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')

# %%
house_containers = html_soup.find_all('table', class_="table table-hover table-striped barcelona")

# %%
first = house_containers[0]
first.find_all('td')
# Out:
# [<td>17 September, 2019</td>,
#  <td>Barcelona</td>,
#  <td><a href="http://data.insideairbnb.com/spain/catalonia/barcelona/2019-09-17/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>,
#  <td>Detailed Listings data for Barcelona</td>,
#  <td>17 September, 2019</td>,
#  <td>Barcelona</td>,
#  <td><a href="http://data.insideairbnb.com/spain/catalonia/barcelona/2019-09-17/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>,
#  <td>Detailed Calendar Data for listings in Barcelona</td>,
#  <td>17 September, 2019</td>,
#  <td>Barcelona</td>,
# ...

# %%
first.find_all('td')[9].get_text()
# Out:
# 'Barcelona'

# %%
first.find_all('td')[0].get_text()
# Out:
# '17 September, 2019'

# %%
first.find_all('td')[1].get_text()
# Out:
# 'Barcelona'

# %%
first.find_all('td')[2].get_text()
# Out:
# 'listings.csv.gz'

# %%
a href

# %%
first.find_all('a href')
# Out:
# []

# %%
for i in first:
    print(i)
# Out:
# <thead>
# <tr>
# <th class="col-md-3" data-field="host_id">Date Compiled</th>
# <th class="col-md-3" data-field="host_id">Country/City</th>
# <th class="col-md-3" data-field="host_id">File Name</th>
# <th class="col-md-3" data-align="right" data-field="count">
#                         Description
#                     </th>
# </tr>
# </thead>
#
#
# <tbody>
# <tr class="">
# <td>17 September, 2019</td>
# <td>Barcelona</td>
# <td><a href="http://data.insideairbnb.com/spain/catalonia/barcelona/2019-09-17/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
# <td>Detailed Listings data for Barcelona</td>
# </tr>
# <tr class="">
# <td>17 September, 2019</td>
# <td>Barcelona</td>
# ...

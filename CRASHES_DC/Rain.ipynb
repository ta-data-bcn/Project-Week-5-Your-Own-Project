# %%
import pandas as pd

# %% [markdown]
# ## Once the dataset is clean, here we order the date column to make sure we can merge this dataframe with the one of the crashes

# %%
meteo = pd.read_csv('../METEO/AEMET_data.csv')

# %%
meteo.head()
# Out:
#    Unnamed: 0       fecha  prec   dir  velmedia  racha horaracha  tmed  tmin  \
# 0           0  2017-01-01   0.0  28.0       1.9    6.1     20:00   NaN   NaN
# 1           1  2017-01-02   0.0  22.0       2.2    9.4     14:30   NaN   NaN
# 2           2  2017-01-03   0.0  34.0       2.8    7.2     08:10   NaN   NaN
# 3           3  2017-01-04   0.0  27.0       2.2    6.7     15:10   NaN   NaN
# 4           4  2017-01-05   0.0  34.0       1.7    7.5     10:00   NaN   NaN
#
#   horatmin  tmax horatmax
# 0      NaN   NaN      NaN
# 1      NaN   NaN      NaN
# 2      NaN   NaN      NaN
# 3      NaN   NaN      NaN
# 4      NaN   NaN      NaN

# %%
meteo[['Any','Mes', 'Dia']] = meteo.fecha.str.split("-",expand=True,)

# %%
meteo.head()
# Out:
#    Unnamed: 0       fecha  prec   dir  velmedia  racha horaracha  tmed  tmin  \
# 0           0  2017-01-01   0.0  28.0       1.9    6.1     20:00   NaN   NaN
# 1           1  2017-01-02   0.0  22.0       2.2    9.4     14:30   NaN   NaN
# 2           2  2017-01-03   0.0  34.0       2.8    7.2     08:10   NaN   NaN
# 3           3  2017-01-04   0.0  27.0       2.2    6.7     15:10   NaN   NaN
# 4           4  2017-01-05   0.0  34.0       1.7    7.5     10:00   NaN   NaN
#
#   horatmin  tmax horatmax   Any Mes Dia
# 0      NaN   NaN      NaN  2017  01  01
# 1      NaN   NaN      NaN  2017  01  02
# 2      NaN   NaN      NaN  2017  01  03
# 3      NaN   NaN      NaN  2017  01  04
# 4      NaN   NaN      NaN  2017  01  05

# %%
meteo.rename(columns={"fecha":"Data"}, inplace=True)

# %%
meteo.Data = meteo.Data.astype('datetime64[ns]')

# %%
meteo.to_csv('rain_clean.csv')

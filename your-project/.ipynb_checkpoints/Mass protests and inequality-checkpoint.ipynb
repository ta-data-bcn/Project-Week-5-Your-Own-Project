# %%
# Libraries

import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Datasets

# Mass mobilization:
carnegiemm_df = pd.read_csv('Data/Global_Protest_Tracker.csv')
harvardmm_df = pd.read_csv('Data/Mass_Mobilization_Harvard.csv')
freedom_df = pd.read_excel('Data/2020_freedom_house_clean.xlsx')

carnegiemm_df_original = carnegiemm_df.copy
harvardmm_df_original = harvardmm_df.copy
freedom_df_original = freedom_df.copy

# %% [markdown]
# ## Carnegie mass mobilization data exploration

# %% [markdown]
# **About the dataset**
#
# Source: https://carnegieendowment.org/publications/interactive/protest-tracker?gclid=Cj0KCQjw6uT4BRD5ARIsADwJQ19KBrMTliLck_-hYMpZhoKbwfuMqAaFWQZbUSb2gFZVszeJ6vKutHcaAvtrEALw_wcB
#
#
# All the protests included had +700 people attending at their peak moment

# %%
# rows, columns

carnegiemm_df.shape
# Out:
# (128, 11)

# %%
carnegiemm_df.head()
# Out:
#      Country                     Protest Name Start Date  \
# 0    Albania         Local elections protests     Feb-19
# 1    Algeria    Protests against “Le Pouvoir”     Feb-19
# 2  Argentina               Austerity protests     Sep-18
# 3  Argentina  Violence against women protests     Apr-20
# 4    Armenia          “#RejectSerzh” protests     Apr-18
#
#   Freedom Rating (Status) at Start Date  \
# 0                           Partly free
# 1                              Not free
# 2                                  Free
# 3                                  Free
# 4                           Partly free
#
#                                             Triggers  \
# 0  Suspicions that Prime Minister Edi Rama engage...
# 1  Then president Abdelaziz Bouteflika’s decision...
# 2  Proposal of austerity measures mandated by the...
# 3  Increasing rates of violence and femicide agai...
# 4  Election of then president Serzh Sargsyan as p...
#
#                                          Motivations   Peak Size  \
# 0                    Electoral fraud and corruption.     >10,000
# 1  Economic downturn, corruption and nepotism, an...  >1,000,000
# 2  Rising inflation and unemployment, as well as ...     >10,000
# 3  Violence against women and lack of resources/i...   Thousands
# 4     Democratic backslide, poverty, and corruption.    >100,000
#
#                                     Key Participants           Duration  \
# 0                                Opposition parties.           5 months
# 1  Opposition parties; a wide range of everyday c...             Active
# 2    Teachers, social organizations, leftist groups.  1 year (sporadic)
# 3                                             Women.            1 month
# 4                      Students, opposition leaders.            2 weeks
#
#                                             Outcomes Unnamed: 10
# 0  No policy/leadership change in response to the...         NaN
# 1  Bouteflika resigned. Military and political el...         NaN
# 2  No policy/leadership change in response to the...         NaN
# 3  The Supreme Court of Mendoza established sever...         NaN
# 4  Sargsyan resigned as prime minister and was su...         NaN

# %%
carnegiemm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Country                                128 non-null    object
#  1   Protest Name                           128 non-null    object
#  2   Start Date                             128 non-null    object
#  3   Freedom Rating (Status) at Start Date  128 non-null    object
#  4   Triggers                               128 non-null    object
#  5   Motivations                            128 non-null    object
#  6   Peak Size                              128 non-null    object
#  7   Key Participants                       128 non-null    object
#  8   Duration                               128 non-null    object
#  9   Outcomes                               128 non-null    object
#  10  Unnamed: 10                            1 non-null      object
# dtypes: object(11)
# memory usage: 11.1+ KB

# %%
# Most interested in Country, Protest Name, Start Date, Freedom Rating, Motivations, Peak Size
carnegiemm_filtered = carnegiemm_df[['Country', 'Protest Name', 'Start Date', 'Freedom Rating (Status) at Start Date', 'Motivations', 'Peak Size']]

# Note: Freedom Rating reflects the rating of a country in the Freedom House’s annual Freedom in the World report at the time the protest started, reflecting the status of political rights and civil liberties in that country.

# %%
# rename freedom rate column
carnegie_filtered = carnegiemm_filtered.rename(columns={'Freedom Rating (Status) at Start Date':'freedom'}, inplace=True)
carnegie_filtered
# Out:
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
# Turn Start Date into just the year + int type

#for csv
carnegiemm_filtered['Year'] = carnegiemm_filtered['Start Date'].str[-2:]
carnegiemm_filtered['Year'] = '20' + carnegiemm_filtered['Year'].astype(str)
carnegiemm_filtered['Year'] = carnegiemm_filtered['Year'].astype(int)
# Out:
# <ipython-input-18-dd3b390e9827>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carnegiemm_filtered['Year'] = carnegiemm_filtered['Start Date'].str[-2:]
# <ipython-input-18-dd3b390e9827>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carnegiemm_filtered['Year'] = '20' + carnegiemm_filtered['Year'].astype(str)
# <ipython-input-18-dd3b390e9827>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   carnegiemm_filtered['Year'] = carnegiemm_filtered['Year'].astype(int)

# %%
carnegiemm_filtered2 = carnegiemm_filtered[['Year', 'Country', 'freedom', 'Protest Name', 'Motivations', 'Peak Size']]
carnegiemm_filtered2
# Out:
#      Year    Country      freedom  \
# 0    2019    Albania  Partly free
# 1    2019    Algeria     Not free
# 2    2018  Argentina         Free
# 3    2020  Argentina         Free
# 4    2018    Armenia  Partly free
# ..    ...        ...          ...
# 123  2018    Uruguay         Free
# 124  2017  Venezuela     Not free
# 125  2019  Venezuela     Not free
# 126  2018    Vietnam     Not free
# 127  2017   Zimbabwe  Partly free
#
#                                      Protest Name  \
# 0                        Local elections protests
# 1                   Protests against “Le Pouvoir”
# 2                              Austerity protests
# 3                 Violence against women protests
# 4                         “#RejectSerzh” protests
# ..                                            ...
# 123                                Farmer protest
# 124              “Mother of All Marches” protests
# 125                         January 2019 protests
# 126  Cybersecurity/special economic zone protests
# 127                                Mugabe protest
#
#                                            Motivations   Peak Size
# 0                      Electoral fraud and corruption.     >10,000
# 1    Economic downturn, corruption and nepotism, an...  >1,000,000
# 2    Rising inflation and unemployment, as well as ...     >10,000
# 3    Violence against women and lack of resources/i...   Thousands
# 4       Democratic backslide, poverty, and corruption.    >100,000
# ..                                                 ...         ...
# 123  Lack of government support for farmers and inc...     >10,000
# 124  Growing authoritarianism, economic crisis, and...     200,000
# 125  Economic collapse, corruption, food shortages,...    >100,000
# 126  Fear of growing Chinese influence through spec...      50,000
# 127  Desire for political reforms and repression un...     >10,000
#
# [128 rows x 6 columns]

# %% [markdown]
# ## Harvard mass mobilization data exploration

# %% [markdown]
# **About the dataset**
#
# Source: https://massmobilization.github.io
#
# Protest is a dichotomous coding for whether or not there was a protest action in a particular period
# The project defines a protest as a gathering of 50 or more people to make a demand of the government. A
# protest action must be targeted at the state or state policy. The project does not code protests in one
# country that are targeted at the policies of another country and in that sense, it captures only “home
# grown” protest activities targeted at state policies.
#
# We are interested in mobilization of anti-state protest, not necessarily community disputes between
# various groups, and therefore we do not code inter-communal demonstrations.
#
# Protests that involve an industrial enterprise that is affected by state policy
# such as labor rights or safety, does represent a codeable activity only if the people take to the streets to
# demand better conditions, wages, safety, and the outcome is a function of state level policy decisions. A
# union action targeted specifically at conditions linked to a specific company and are part of labor
# negotiations do not constitute a protest, unless or until the labor action becomes a public event (by, say,
# marching in the streets or demanding action on the part of the government).

# %%
# rows, columns
harvardmm_df.shape
# Out:
# (16363, 31)

# %%
harvardmm_df.head()
# Out:
#           id country  ccode  year         region  protest  protestnumber  \
# 0  201990001  Canada     20  1990  North America        1              1
# 1  201990002  Canada     20  1990  North America        1              2
# 2  201990003  Canada     20  1990  North America        1              3
# 3  201990004  Canada     20  1990  North America        1              4
# 4  201990005  Canada     20  1990  North America        1              5
#
#    startday  startmonth  startyear  ...  protesterdemand4   stateresponse1  \
# 0      15.0         1.0     1990.0  ...               NaN           ignore
# 1      25.0         6.0     1990.0  ...               NaN           ignore
# 2       1.0         7.0     1990.0  ...               NaN           ignore
# 3      12.0         7.0     1990.0  ...               NaN     accomodation
# 4      14.0         8.0     1990.0  ...               NaN  crowd dispersal
#
#    stateresponse2  stateresponse3 stateresponse4 stateresponse5  \
# 0             NaN             NaN            NaN            NaN
# 1             NaN             NaN            NaN            NaN
# 2             NaN             NaN            NaN            NaN
# 3             NaN             NaN            NaN            NaN
# 4         arrests    accomodation            NaN            NaN
#
#   stateresponse6 stateresponse7  \
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
#                                              sources  \
# 0  1. Great Canadian train journeys into history;...
# 1  1. Autonomy s Cry Revived in Quebec The New Yo...
# 2  1. Quebec protest after Queen calls for unity ...
# 3  1. Indians Gather as Siege Intensifies; Armed ...
# 4  1. Dozens hurt in Mohawk blockade protest The ...
#
#                                                notes
# 0   Canada s railway passenger system was finally...
# 1  protestors were only identified as  young peop...
# 2   THE Queen, after calling on Canadians to rema...
# 3   Canada s federal government has agreed to acq...
# 4  Protests were directed against the state due t...
#
# [5 rows x 31 columns]

# %%
harvardmm_df.tail()
# Out:
#                id           country  ccode  year   region  protest  \
# 16358  9102017001  Papua New Guinea    910  2017  Oceania        1
# 16359  9102017002  Papua New Guinea    910  2017  Oceania        1
# 16360  9102017003  Papua New Guinea    910  2017  Oceania        1
# 16361  9102018000  Papua New Guinea    910  2018  Oceania        0
# 16362  9102019000  Papua New Guinea    910  2019  Oceania        0
#
#        protestnumber  startday  startmonth  startyear  ...  protesterdemand4  \
# 16358              1      15.0         6.0     2017.0  ...               NaN
# 16359              2      15.0         7.0     2017.0  ...               NaN
# 16360              3      31.0        10.0     2017.0  ...               NaN
# 16361              0       NaN         NaN        NaN  ...               NaN
# 16362              0       NaN         NaN        NaN  ...                 .
#
#         stateresponse1  stateresponse2  stateresponse3 stateresponse4  \
# 16358     accomodation             NaN             NaN            NaN
# 16359  crowd dispersal             NaN             NaN            NaN
# 16360           ignore             NaN             NaN            NaN
# 16361              NaN             NaN             NaN            NaN
# 16362              NaN             NaN             NaN            NaN
#
#       stateresponse5 stateresponse6 stateresponse7  \
# 16358            NaN            NaN            NaN
# 16359            NaN            NaN            NaN
# 16360            NaN            NaN            NaN
# 16361            NaN            NaN            NaN
# 16362              .            NaN            NaN
#
#                                                  sources  \
# 16358   Bougainville imposes moratorium on Panguna mi...
# 16359   Violence, chaos and fraud: fraught Papua New ...
# 16360   Refugees dig in as camp closes; Manus   Situa...
# 16361                                                NaN
# 16362                                                NaN
#
#                                                    notes
# 16358  The Bougainville government has enacted an ind...
# 16359  Peter O Neill has been reappointed as prime mi...
# 16360  Refugees on Manus Island were braced for poten...
# 16361                                                NaN
# 16362                                                NaN
#
# [5 rows x 31 columns]

# %%
harvardmm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16363 entries, 0 to 16362
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     16363 non-null  int64
#  1   country                16363 non-null  object
#  2   ccode                  16363 non-null  int64
#  3   year                   16363 non-null  int64
#  4   region                 16363 non-null  object
#  5   protest                16363 non-null  int64
#  6   protestnumber          16363 non-null  int64
#  7   startday               14514 non-null  float64
#  8   startmonth             14514 non-null  float64
#  9   startyear              14514 non-null  float64
#  10  endday                 14514 non-null  float64
#  11  endmonth               14514 non-null  float64
#  12  endyear                14514 non-null  float64
#  13  protesterviolence      15033 non-null  float64
#  14  location               14493 non-null  object
#  15  participants_category  9160 non-null   object
#  16  participants           15021 non-null  object
#  17  protesteridentity      13959 non-null  object
#  18  protesterdemand1       14503 non-null  object
#  19  protesterdemand2       2676 non-null   object
#  20  protesterdemand3       316 non-null    object
#  21  protesterdemand4       896 non-null    object
#  22  stateresponse1         14483 non-null  object
#  23  stateresponse2         2716 non-null   object
#  24  stateresponse3         850 non-null    object
#  25  stateresponse4         230 non-null    object
#  26  stateresponse5         926 non-null    object
#  27  stateresponse6         16 non-null     object
#  28  stateresponse7         920 non-null    object
#  29  sources                14510 non-null  object
#  30  notes                  14468 non-null  object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 3.9+ MB

# %%
# Harvard dataset includes some rows were protests are not deemed relevant. These are indicated with a 0 in the column 'protests'
# I drop these lines since they are irrelevant to the current analysis

harvardmm_filtered = harvardmm_df[harvardmm_df['protest'] !=0]

# Most interested in Year, Country, Protest Name(protesterdemand1), Motivations (protesterdemand2), Peak Size (participants)
harvardmm_filtered = harvardmm_filtered[['year', 'country', 'protesterdemand1', 'protesterdemand2', 'participants']]
harvardmm_filtered
# Out:
#        year           country             protesterdemand1  \
# 0      1990            Canada  political behavior, process
# 1      1990            Canada  political behavior, process
# 2      1990            Canada  political behavior, process
# 3      1990            Canada              land farm issue
# 4      1990            Canada  political behavior, process
# ...     ...               ...                          ...
# 16355  2014  Papua New Guinea  political behavior, process
# 16357  2016  Papua New Guinea        removal of politician
# 16358  2017  Papua New Guinea  political behavior, process
# 16359  2017  Papua New Guinea  political behavior, process
# 16360  2017  Papua New Guinea  political behavior, process
#
#          protesterdemand2 participants
# 0      labor wage dispute        1000s
# 1                     NaN         1000
# 2                     NaN          500
# 3                     NaN         100s
# 4                     NaN          950
# ...                   ...          ...
# 16355                 NaN         100+
# 16357                 NaN   About 1000
# 16358     land farm issue          50+
# 16359                 NaN          50+
# 16360                 NaN    About 100
#
# [14514 rows x 5 columns]

# %%
# I want to add the freedom index from randomhouse to the harvard dataset too
# For this, replicate the years vertically and add the value per row and column downwards
freedom = freedom_df.copy()
freedom.rename(columns={'Year(s) Under Review':'country'}, inplace = True)
freedom.head()
# Out:
#        country 1990 1991 1992 1993 1994 1995 1996 1997 1998  ... 2010 2011  \
# 0  Afghanistan   NF   NF   NF   NF   NF   NF   NF   NF   NF  ...   NF   NF
# 1      Albania   NF   PF   PF   PF   PF   PF   PF   PF   PF  ...   PF   PF
# 2      Algeria   PF   PF   NF   NF   NF   NF   NF   NF   NF  ...   NF   NF
# 3      Andorra    -    -    -    F    F    F    F    F    F  ...    F    F
# 4       Angola   NF   PF   NF   NF   NF   NF   NF   NF   NF  ...   NF   NF
#
#   2012 2013 2014 2015 2016 2017 2018 2019
# 0   NF   NF   NF   NF   NF   NF   NF   NF
# 1   PF   PF   PF   PF   PF   PF   PF   PF
# 2   NF   NF   NF   NF   NF   NF   NF   NF
# 3    F    F    F    F    F    F    F    F
# 4   NF   NF   NF   NF   NF   NF   NF   NF
#
# [5 rows x 31 columns]

# %%
# check that country returns the desired column
freedom['country']
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3          Andorra
# 4           Angola
#           ...
# 200      Yemen, N.
# 201      Yemen, S.
# 202     Yugoslavia
# 203         Zambia
# 204       Zimbabwe
# Name: country, Length: 205, dtype: object

# %%
# prepare list for melt
list_of_cols = list(freedom.columns)

# %%
# melt
pivoted = pd.melt(freedom, id_vars = ['country'], value_vars=list_of_cols[1:], var_name = 'year', value_name='freedom')
pivoted.head()
# Out:
#        country  year freedom
# 0  Afghanistan  1990      NF
# 1      Albania  1990      NF
# 2      Algeria  1990      PF
# 3      Andorra  1990       -
# 4       Angola  1990      NF

# %%
pivoted.shape
# Out:
# (6150, 3)

# %%
# insert pivoted into harvardmm_filtered
harvard_merged = harvardmm_filtered.merge(pivoted, on=['country', 'year'], how = 'left')
harvard_merged

#Check: the df keeps the same number of rows as harvardmm_filtered
# Out:
#        year           country             protesterdemand1  \
# 0      1990            Canada  political behavior, process
# 1      1990            Canada  political behavior, process
# 2      1990            Canada  political behavior, process
# 3      1990            Canada              land farm issue
# 4      1990            Canada  political behavior, process
# ...     ...               ...                          ...
# 14509  2014  Papua New Guinea  political behavior, process
# 14510  2016  Papua New Guinea        removal of politician
# 14511  2017  Papua New Guinea  political behavior, process
# 14512  2017  Papua New Guinea  political behavior, process
# 14513  2017  Papua New Guinea  political behavior, process
#
#          protesterdemand2 participants freedom
# 0      labor wage dispute        1000s       F
# 1                     NaN         1000       F
# 2                     NaN          500       F
# 3                     NaN         100s       F
# 4                     NaN          950       F
# ...                   ...          ...     ...
# 14509                 NaN         100+      PF
# 14510                 NaN   About 1000      PF
# 14511     land farm issue          50+      PF
# 14512                 NaN          50+      PF
# 14513                 NaN    About 100      PF
#
# [14514 rows x 6 columns]

# %%
# change names so that they are the same as in carnegiemm_filtered2

harvard_merged['freedom'] = harvard_merged['freedom'].str.replace('NF','Not free')
harvard_merged['freedom'] = harvard_merged['freedom'].str.replace('PF','Partly free')
harvard_merged['freedom'] = harvard_merged['freedom'].str.replace('F','Free')
harvard_merged
# Out:
#        year           country             protesterdemand1  \
# 0      1990            Canada  political behavior, process
# 1      1990            Canada  political behavior, process
# 2      1990            Canada  political behavior, process
# 3      1990            Canada              land farm issue
# 4      1990            Canada  political behavior, process
# ...     ...               ...                          ...
# 14509  2014  Papua New Guinea  political behavior, process
# 14510  2016  Papua New Guinea        removal of politician
# 14511  2017  Papua New Guinea  political behavior, process
# 14512  2017  Papua New Guinea  political behavior, process
# 14513  2017  Papua New Guinea  political behavior, process
#
#          protesterdemand2 participants      freedom
# 0      labor wage dispute        1000s         Free
# 1                     NaN         1000         Free
# 2                     NaN          500         Free
# 3                     NaN         100s         Free
# 4                     NaN          950         Free
# ...                   ...          ...          ...
# 14509                 NaN         100+  Partly free
# 14510                 NaN   About 1000  Partly free
# 14511     land farm issue          50+  Partly free
# 14512                 NaN          50+  Partly free
# 14513                 NaN    About 100  Partly free
#
# [14514 rows x 6 columns]

# %%
# rename columns
harvard_merged_rename=harvard_merged.rename(columns={"year": "Year", "country": "Country", "protesterdemand1": "Protest Name", "protesterdemand2": "Motivations", "participants":"Peak Size"})

# %%
#put the columns in the same order
harvard_merged_rename = harvard_merged_rename[['Year', 'Country', 'freedom', 'Protest Name', 'Motivations', 'Peak Size']]
harvard_merged_rename
# Out:
#        Year           Country      freedom                 Protest Name  \
# 0      1990            Canada         Free  political behavior, process
# 1      1990            Canada         Free  political behavior, process
# 2      1990            Canada         Free  political behavior, process
# 3      1990            Canada         Free              land farm issue
# 4      1990            Canada         Free  political behavior, process
# ...     ...               ...          ...                          ...
# 14509  2014  Papua New Guinea  Partly free  political behavior, process
# 14510  2016  Papua New Guinea  Partly free        removal of politician
# 14511  2017  Papua New Guinea  Partly free  political behavior, process
# 14512  2017  Papua New Guinea  Partly free  political behavior, process
# 14513  2017  Papua New Guinea  Partly free  political behavior, process
#
#               Motivations   Peak Size
# 0      labor wage dispute       1000s
# 1                     NaN        1000
# 2                     NaN         500
# 3                     NaN        100s
# 4                     NaN         950
# ...                   ...         ...
# 14509                 NaN        100+
# 14510                 NaN  About 1000
# 14511     land farm issue         50+
# 14512                 NaN         50+
# 14513                 NaN   About 100
#
# [14514 rows x 6 columns]

# %%
# drop 2017 data since it is more complete in the carnegie datasets
harvard_merged_rename = harvard_merged_rename[harvard_merged_rename.Year!=2017]
harvard_merged_rename
# Out:
#        Year           Country      freedom                 Protest Name  \
# 0      1990            Canada         Free  political behavior, process
# 1      1990            Canada         Free  political behavior, process
# 2      1990            Canada         Free  political behavior, process
# 3      1990            Canada         Free              land farm issue
# 4      1990            Canada         Free  political behavior, process
# ...     ...               ...          ...                          ...
# 14506  2012  Papua New Guinea  Partly free  political behavior, process
# 14507  2012  Papua New Guinea  Partly free  political behavior, process
# 14508  2013  Papua New Guinea  Partly free  political behavior, process
# 14509  2014  Papua New Guinea  Partly free  political behavior, process
# 14510  2016  Papua New Guinea  Partly free        removal of politician
#
#               Motivations   Peak Size
# 0      labor wage dispute       1000s
# 1                     NaN        1000
# 2                     NaN         500
# 3                     NaN        100s
# 4                     NaN         950
# ...                   ...         ...
# 14506                 NaN        1000
# 14507                 NaN       1000s
# 14508                 NaN        2000
# 14509                 NaN        100+
# 14510                 NaN  About 1000
#
# [13974 rows x 6 columns]

# %% [markdown]
# ## Mass mobilization dataset

# %% [markdown]
# I will incorporate only the data of protests with more than 1000 people attending at its peak moment.

# %%
# Concatenate both datasets. I want to keep carnegiemm_filtered2 unaltered and add the values of harvard_merged to the df
protests=pd.concat([carnegiemm_filtered2,harvard_merged_rename],axis=0)#top/bottom

# %%
# Rename columns to more callable names
protests= protests.rename(columns={"Protest Name": "Protest_Name", "Peak Size": "Peak_Size"})

# %%
protests
# Out:
#        Year           Country      freedom                     Protest_Name  \
# 0      2019           Albania  Partly free         Local elections protests
# 1      2019           Algeria     Not free    Protests against “Le Pouvoir”
# 2      2018         Argentina         Free               Austerity protests
# 3      2020         Argentina         Free  Violence against women protests
# 4      2018           Armenia  Partly free          “#RejectSerzh” protests
# ...     ...               ...          ...                              ...
# 14506  2012  Papua New Guinea  Partly free      political behavior, process
# 14507  2012  Papua New Guinea  Partly free      political behavior, process
# 14508  2013  Papua New Guinea  Partly free      political behavior, process
# 14509  2014  Papua New Guinea  Partly free      political behavior, process
# 14510  2016  Papua New Guinea  Partly free            removal of politician
#
#                                              Motivations   Peak_Size
# 0                        Electoral fraud and corruption.     >10,000
# 1      Economic downturn, corruption and nepotism, an...  >1,000,000
# 2      Rising inflation and unemployment, as well as ...     >10,000
# 3      Violence against women and lack of resources/i...   Thousands
# 4         Democratic backslide, poverty, and corruption.    >100,000
# ...                                                  ...         ...
# 14506                                                NaN        1000
# 14507                                                NaN       1000s
# 14508                                                NaN        2000
# 14509                                                NaN        100+
# 14510                                                NaN  About 1000
#
# [14102 rows x 6 columns]

# %%
# save dataframe
protests.to_csv('./Data/protests.csv', encoding='utf-8')

# %%
# Peak_Size column cleanup
protests.isnull().sum(axis = 0)
# Out:
# Year                0
# Country             0
# freedom           492
# Protest_Name       11
# Motivations     11410
# Peak_Size          12
# dtype: int64

# %%
protests.Peak_Size.fillna('', inplace=True)

# %%
protests.Peak_Size.unique()
# Out:
# array(['>10,000', '>1,000,000', 'Thousands', '>100,000', '30,000',
#        '5,000', '15,000', '>1,000', '1,500,000', 'Hundreds', 'Unknown',
#        '20,000', '250,000', '4000', '200,000', '300,000', '800,000',
#        '10,000', '40,000', '18,000', '22,000', '2,000,000', '100,000',
#        '2000', '1,000,000', '12,500', 'Tens of thousands', '4,000',
#        '60,000', '50,000', '60000', '500,000', '2,000', '37,500',
#        '65,000', '1.5 million', '600,000', '62,500', '12,000',
#        '1 million', '>700', '1000s', '1000', '500', '100s', '950', '200',
#        '110000', '10000s', '10000', '6000', '3000', '126000', '45000',
#        '400', '10s', '250', '170000', '300', '12000', '1500', '50+',
#        '250-300', 'hundreds', 'more than 200', 'dozens', 'a group',
#        'about 300', 'more than 500', 'busloads', 'widespread',
#        'thousands', '100', '50', '100+', '80', '2500', '150',
#        '100s-1000s', '8000', '100s-1000', '300-1000s', '15000', '600',
#        '1500+', 'about 2000', 'several hundred', 'tens of thousands',
#        '270', '350', '5000', '20000', '100s-10000s', '100000', '30000',
#        '70000', '1100-10000s', '80000', '60', '200000', '100000s',
#        '750000', '90000', '150000', '400000', '1000000', '1000+', '>50',
#        '>50000', 'several dozen', '180', '50s', '35000', '', '40000',
#        '130', '23000+', '14000', '900', '1200', '1700', '700', '800',
#        '5000+', '50000', 'more than 1000', '280', '3000+', '2400', '90',
#        '15000+', 'hundreds ', 'hundreds of thousands', '164 arrested',
#        '1000s-10000', '7000', '25000', '240000', '1100', '4500', '75000',
#        '250000', '500000', '300000', '120000', '13800', '600000',
#        '800000', '900000', '700000', '350000', '450000', '5,000,000',
#        '53000', '280000', '>5000', '72000', '270000', '1,000,000s',
#        '1300000', '22000', '135000', '9000', '290000', '44000', '36000',
#        '168000', '11000', 'several dozen arrests', 'several thousand',
#        'more than 400 arrested', 'Hundreds of thousands', '20 arrested',
#        '>100', '300 arrested', '16 killed', '75', '1400', '4800', '2450',
#        '6500', '181', '32000', '18500', '.', 'a few dozen', '24000',
#        '260000', '13000', '1150', '55', '450', '920', '16000', '3500',
#        '>15000', 'more than 50000', '55000', '1300', '3800', '17000',
#        '>1000000', '>2000000', '>1000', '25 protesters injured',
#        'hundreds of thousands to 1.4 million', 'scores',
#        'more than a dozen schools', 'a few thousand', 'Several thousand',
#        'About 2,000 ', 'dozens arrested ', '70', '609',
#        'over 100 arrested', '200+', '118000', '8500', '2850', '28000',
#        '2200', 'more than 25000', '130000', '100,000s', '1250', '17200',
#        '>200', '>3100', '>2900', '>5100', '2050', '<100', '10000+',
#        '> 50', 'Thousands ', '107', '100s+', '>150', '>2500', '< 1500',
#        '> 100', '> 10000', '> 70', '> 700', '> 200', '30000+', '>2000',
#        '12500', '600+', '> 3000', '>3000', '2000-3000', '>370', '13000+',
#        '2500+', '130+', '80+', '500+ ', '407791', '23000', '12000+',
#        'very low thousands', '150+', '22500', '250+', '2200+', '6000+',
#        '52000', '60+', '>300', '>400', '20700+', '2000+', '430000+',
#        '400+', '1600+', 'several hundreds', '4000+', '120', '160',
#        '>250-300', '100000+', 'Nearly 700,000', '<5000', 'About 100',
#        '>15,000', '>10000', '355', '500+', '5500', '800+', '520+', '64+',
#        '70+', '350+', '141', '240', '300+', '27000', '700+', '50000+',
#        '7500', '25000+', '20000+', '5600+', 'About 80',
#        'between 35,000 and 50,000', '325000', '300-400', '34000',
#        'About 3,000', '>30000', '>150000', '<10000', '<20000', '>280',
#        '>350', '>60900', '>100000', '>300000', '>500000', '2000000',
#        '>80', '>35000', '>250', '>1100', '>2600', '>20000', '>130', '750',
#        '<6700', '>400000', '570000', '200-300', '>18000', '<375000',
#        '1200000', '465000', '150-300', '<400000', '825000', '1100000',
#        '4000-12000', '560000', '61', '340000', '125000', '17000+',
#        '1365+', '20000-60000', '119500', 'hundreds  ', '66000', '29000',
#        '84000', '69000', '58000', '51000', '1000000s', '<1000000',
#        '>200000', '18000', '<200000', '1500-2000', '500000+',
#        'several 1000s', '> 30000', '> 150000', '> 100000', '< 100000 ',
#        '> 70000', '> 80000', '> 300000', '> 500000', '> 200000',
#        'hundreds of thousands ', '> 400000', '>7000', '140', '6600',
#        '484000', '340', '14500', '17500', '25100+', '260-500', '3200+',
#        '> 5000', '65000', 'Dozens', '> 35000', '650000', '> 1000',
#        '> 500', 'nearly 10000', '> 300', 'several dozens', '> 1500',
#        '1000s-23000', '24000+', '> 20000', '90000+', '5750', '> 15000',
#        'millions', '> 1000000', '> 450', '100000s-3000000', '298',
#        '1500000', '>1200', '>340', '>70000', '28 LGBT groups', '> 9000',
#        '> 42000', '> 40000', 'At least 10,000', '70000+', '4700+',
#        '300000+', '56000+', '9000+', '7000+', '> 50000', '> 1300',
#        '> 2000', '>8000', '>4000', '>6000', '>37000', '20000-40000',
#        '40000-80000', '>80000', '<300', '840', 'teachers and pupils',
#        'few thousand', '185', '>170', '1000S', '>56', '>40000', '>1500',
#        '>9000', '>16000', '7000-15000', '<1000', '<50', '<15000',
#        'between 100000 & 300000', 'several hundred thousands',
#        '6000 to 8000', '3000 to 5000', '> 800', '> 3500', '> 50 ',
#        'a few thousand ', '> 25000', 'couple thousands', '> 23000',
#        '> 60000', '> 400', '170', '<500', '300-350', '>213',
#        '50000-70000', '41000', '58000+', 'at least 500', 'about 100',
#        'between 7500-25000', '> 50 < 100 ', '6000-8000', '600-700',
#        '350-400', '>500', '60-70', '7000-9000', '150-200', '3500-5000',
#        '35000 - 70000', '193', '2600', '106', '1500-10000', '50 arrested',
#        '90+', '613', '128', '335', '50-100', 'btw. 20000 & 30000', '50_',
#        '3000-4000', '500000-700000', '<2000', '80-100', '8000-9000',
#        '400-500', '3765', '311', '>3,000 ', '5000-10000', '700 - >1000',
#        '51+', 'Over 3,000', 'Over 100', '>115', 'About 1000',
#        'scores (>50)', 'a few hundred', '86', '<200', 'several thousand ',
#        '71', '63', '>459', '>60', '>600', '2000 to 3000',
#        '2,000 to 3,000', '>50-1000', '100s-500', '157', '1300+', '65',
#        '132+', '2700', '50000-120000', '500-1000', '30000-40000',
#        '200000-400000', '50000-80000', '3000-10000', '2400+', '1300-2000',
#        '89', '567+', '73', '200-2000+', '400-600+', '200-400', '200-3000',
#        '100-1500+', '125', '207', '500-700', '260', '195', '>800', '>224',
#        '<900', '50-99', '14059', '3500+', '500-2000', '6000-7000',
#        '600-3000', '100000-200000', '200000+', '300-500', '800-900',
#        '1800+', '500-1200', '3000-5000', '3000-6000', '388', '50-60',
#        '>70', '1000s-40000', 'around 50', 'dozens arrested', '100s-10000',
#        'about 150', 'about 3000', '1600', '40', '100S', '29', '>50-100s',
#        '2000-200000', '1000-10000', '5000-50000', '1000s-10000s',
#        'few dozen', '650', 'more than 2000', '10000s ', '3600', '51000+',
#        '>55', '79', '680', '4360', '370', '850', '5600', '82000', '68000',
#        '63000', '27500', '28500', '>1600', '180000', '510000',
#        'About 4,000 people',
#        'The organisers said more than 3,000 people; police said the turnout was 830 at its peak',
#        'About 6,000 people', 'Hundreds of people', 'Hundreds of workers',
#        'Estimated number of protesters at 10,000', 'Thousands of miners',
#        'Over 2,000 construction workers', 'Nearly 70 parents',
#        'More than 1,000 teachers', 'Several hundred demonstrators',
#        'More than 300 people', 'About 50 activists',
#        'Hundreds of villagers', '2,000 to 4,000 people',
#        'About 100 taxis', 'Thousands of people',
#        'The Civil Human Rights Front said 110,000 people; The Hong Kong police said about 20,000',
#        'More than 10,000 protesters', '13,000 people',
#        'March organiser and legal-sector lawmaker Dennis Kwok, said more than 2,000 people joined the protest. Police put the turnout at 1,700.',
#        '3000000', '320000', '124000', '>32200', 'more than 100', '330',
#        '137000', '54', '61000', '465', '10600', '19000', '625000', '161',
#        '138', '5300', '634', '102000', '5800', '4200', '149', '540',
#        '57000', '21000', '33000', '140+', 'Some 5,000 members',
#        'More than 10,000 citizens', 'A few hundred', '<70000', '10300',
#        'Between 11000 and 45000', '75000-170000', '65,000 people',
#        'About 2,000 people', 'Tens of thousands of people', '84',
#        'At least 100', 'As many as 25,000 protesters', '>5,000', '102',
#        '155', '66', '210', '76', '74', '115', '112', '93000', '52',
#        '7000000', '20000s', '300s', '>440', 'Nearly 500', '>222',
#        'About 500', 'Over 200 local protesters', 'About 200',
#        'About 4000', '241', '87', '51', 'More than 100 people',
#        'About 500 demonstrators', '2300', '3700',
#        'Some 100 demonstrators', 'About 50 protesters',
#        'Around 300 local people', 'Up to 300 people',
#        '97 public organisations',
#        'About 100 activists, including 39 suspects who were summoned, and 66 more suspects who would be summoned to face charges later',
#        'About 200 people', '50 people', 'ABOUT 130 members',
#        '20000-30000', 'More than 4,000 people', '234', '1900', '64',
#        '25000-200000', '50000-100000', 'About 300 people',
#        'Some 500 people', 'Almost 200', '1,800 participants',
#        '57 former estate workers', 'Some 250 residents',
#        'Nearly 500 supporters', 'Some 100 residents', 'Some 50 members',
#        'SOME 3,000 people', 'About 100 people', 'Estimated to be 15,500',
#        'About 300 protesters', 'About 300', '88', '500-600', 'About 120',
#        '3000-4500', 'About 12,000 protesters', '1800',
#        'Estimated 6,000 drivers', 'About 150 protesters',
#        'More than 500,000 people', 'More than 1,000', 'About 10000',
#        '559'], dtype=object)

# %%
import re

def number_cleaner(text):
    a = re.findall(r'[-><]\s*(\d+)', text)
    if a == []:
        b = re.findall(r'\d+', text)
        if b ==[]:
            return text
        else:
            return b[0]
    else:
        return a[0]

protests['Peak_Size'] = protests.Peak_Size.apply(number_cleaner)

# %%
# Analysis of Peak_Size column for cleaning

protests.Peak_Size.unique()
# Out:
# array(['10', '1', 'Thousands', '100', '30', '5', '15', 'Hundreds',
#        'Unknown', '20', '250', '4000', '200', '300', '800', '40', '18',
#        '22', '2', '2000', '12', 'Tens of thousands', '4', '60', '50',
#        '60000', '500', '37', '65', '600', '62', '700', '1000', '950',
#        '110000', '10000', '6000', '3000', '126000', '45000', '400',
#        '170000', '12000', '1500', 'hundreds', 'dozens', 'a group',
#        'busloads', 'widespread', 'thousands', '80', '2500', '150', '8000',
#        '15000', 'several hundred', 'tens of thousands', '270', '350',
#        '5000', '20000', '100000', '30000', '70000', '80000', '200000',
#        '750000', '90000', '150000', '400000', '1000000', '50000',
#        'several dozen', '180', '35000', '', '40000', '130', '23000',
#        '14000', '900', '1200', '1700', '280', '2400', '90', 'hundreds ',
#        'hundreds of thousands', '164', '7000', '25000', '240000', '1100',
#        '4500', '75000', '250000', '500000', '300000', '120000', '13800',
#        '600000', '800000', '900000', '700000', '350000', '450000',
#        '53000', '280000', '72000', '270000', '1300000', '22000', '135000',
#        '9000', '290000', '44000', '36000', '168000', '11000',
#        'several dozen arrests', 'several thousand',
#        'Hundreds of thousands', '16', '75', '1400', '4800', '2450',
#        '6500', '181', '32000', '18500', '.', 'a few dozen', '24000',
#        '260000', '13000', '1150', '55', '450', '920', '16000', '3500',
#        '55000', '1300', '3800', '17000', '2000000', '25', 'scores',
#        'more than a dozen schools', 'a few thousand', 'Several thousand',
#        'dozens arrested ', '70', '609', '118000', '8500', '2850', '28000',
#        '2200', '130000', '1250', '17200', '3100', '2900', '5100', '2050',
#        'Thousands ', '107', '12500', '370', '407791',
#        'very low thousands', '22500', '52000', '20700', '430000', '1600',
#        'several hundreds', '120', '160', '355', '5500', '520', '64',
#        '141', '240', '27000', '7500', '5600', '35', '325000', '34000',
#        '3', '60900', '2600', '750', '6700', '570000', '18000', '375000',
#        '1200000', '465000', '825000', '1100000', '560000', '61', '340000',
#        '125000', '1365', '119500', 'hundreds  ', '66000', '29000',
#        '84000', '69000', '58000', '51000', 'hundreds of thousands ',
#        '140', '6600', '484000', '340', '14500', '17500', '25100', '3200',
#        '65000', 'Dozens', '650000', 'several dozens', '5750', 'millions',
#        '3000000', '298', '1500000', '28', '42000', '4700', '56000',
#        '37000', '840', 'teachers and pupils', 'few thousand', '185',
#        '170', '56', 'several hundred thousands', 'a few thousand ',
#        'couple thousands', '213', '41000', '193', '106', '613', '128',
#        '335', '3765', '311', '51', '115', 'a few hundred', '86',
#        'several thousand ', '71', '63', '459', '157', '132', '2700', '89',
#        '567', '73', '125', '207', '260', '195', '224', '99', '14059',
#        '1800', '388', 'dozens arrested', '29', 'few dozen', '650', '3600',
#        '79', '680', '4360', '850', '82000', '68000', '63000', '27500',
#        '28500', '180000', '510000', '6', 'Hundreds of people',
#        'Hundreds of workers', 'Thousands of miners',
#        'Several hundred demonstrators', 'Hundreds of villagers',
#        'Thousands of people', '110', '13', '320000', '124000', '32200',
#        '330', '137000', '54', '61000', '465', '10600', '19000', '625000',
#        '161', '138', '5300', '634', '102000', '5800', '4200', '149',
#        '540', '57000', '21000', '33000', 'A few hundred', '10300',
#        'Tens of thousands of people', '84', '102', '155', '66', '210',
#        '76', '74', '112', '93000', '52', '7000000', '440', '222', '241',
#        '87', '2300', '3700', '97', '234', '1900', '57', '88', '559'],
#       dtype=object)

# %%
protests.loc[protests['Peak_Size'] =='dozens','Peak_Size'] ='12'
protests.loc[protests['Peak_Size'] =='several dozen','Peak_Size'] ='12'
protests.loc[protests['Peak_Size'] =='a group','Peak_Size'] ='unknown'
protests.loc[protests['Peak_Size'] =='busloads','Peak_Size'] ='unknown'
protests.loc[protests['Peak_Size'] =='widespread','Peak_Size'] ='unknown'
protests.loc[protests['Peak_Size'] =='Hundreds','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='hundreds','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='hundreds ','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='several hundred','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='several thousand','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='Thousands','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='Tens of thousands','Peak_Size'] ='10000'
protests.loc[protests['Peak_Size'] =='tens of thousands','Peak_Size'] ='10000'
protests.loc[protests['Peak_Size'] =='hundreds of thousands','Peak_Size'] ='100000'
protests.loc[protests['Peak_Size'] =='several dozen arrests','Peak_Size'] ='unknown'

# %%
protests.loc[protests['Peak_Size'] =='a few dozen','Peak_Size'] ='12'
protests.loc[protests['Peak_Size'] =='thousands','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='a few thousand','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='Several thousand','Peak_Size'] ='1000'

protests.loc[protests['Peak_Size'] =='scores','Peak_Size'] ='unknown'
protests.loc[protests['Peak_Size'] =='more than a dozen schools','Peak_Size'] ='12'
protests.loc[protests['Peak_Size'] =='dozens arrested ','Peak_Size'] ='unknown'
protests.loc[protests['Peak_Size'] =='Thousands ','Peak_Size'] ='1000'

protests.loc[protests['Peak_Size'] =='very low thousands','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='several hundreds','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='hundreds  ','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='hundreds of thousands ','Peak_Size'] ='100000'

# %%
protests.loc[protests['Peak_Size'] =='Hundreds of thousands','Peak_Size'] ='100000'
protests.loc[protests['Peak_Size'] =='Dozens','Peak_Size'] ='12'
protests.loc[protests['Peak_Size'] =='several dozens','Peak_Size'] ='12'
protests.loc[protests['Peak_Size'] =='millions','Peak_Size'] ='1000000'

protests.loc[protests['Peak_Size'] =='teachers and pupils','Peak_Size'] ='unknown'
protests.loc[protests['Peak_Size'] =='few thousand','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='several hundred thousands','Peak_Size'] ='100000'
protests.loc[protests['Peak_Size'] =='a few thousand ','Peak_Size'] ='1000'

protests.loc[protests['Peak_Size'] =='couple thousands','Peak_Size'] ='2000'
protests.loc[protests['Peak_Size'] =='a few hundred','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='several thousand ','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='dozens arrested','Peak_Size'] ='unknown'

# %%
protests.loc[protests['Peak_Size'] =='Hundreds of people','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='Hundreds of workers','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='Thousands of miners','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='Several hundred demonstrators','Peak_Size'] ='100'


protests.loc[protests['Peak_Size'] =='Hundreds of villagers','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='Thousands of people','Peak_Size'] ='1000'
protests.loc[protests['Peak_Size'] =='A few hundred','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='Tens of thousands of people','Peak_Size'] ='100'

# %%
protests.loc[protests['Peak_Size'] =='few dozen','Peak_Size'] ='100'
protests.loc[protests['Peak_Size'] =='Unknown','Peak_Size'] ='unknown'

# %%
protests.Peak_Size.unique()
# Out:
# array(['10', '1', '1000', '100', '30', '5', '15', 'unknown', '20', '250',
#        '4000', '200', '300', '800', '40', '18', '22', '2', '2000', '12',
#        '10000', '4', '60', '50', '60000', '500', '37', '65', '600', '62',
#        '700', '950', '110000', '6000', '3000', '126000', '45000', '400',
#        '170000', '12000', '1500', '80', '2500', '150', '8000', '15000',
#        '270', '350', '5000', '20000', '100000', '30000', '70000', '80000',
#        '200000', '750000', '90000', '150000', '400000', '1000000',
#        '50000', '180', '35000', '', '40000', '130', '23000', '14000',
#        '900', '1200', '1700', '280', '2400', '90', '164', '7000', '25000',
#        '240000', '1100', '4500', '75000', '250000', '500000', '300000',
#        '120000', '13800', '600000', '800000', '900000', '700000',
#        '350000', '450000', '53000', '280000', '72000', '270000',
#        '1300000', '22000', '135000', '9000', '290000', '44000', '36000',
#        '168000', '11000', '16', '75', '1400', '4800', '2450', '6500',
#        '181', '32000', '18500', '.', '24000', '260000', '13000', '1150',
#        '55', '450', '920', '16000', '3500', '55000', '1300', '3800',
#        '17000', '2000000', '25', '70', '609', '118000', '8500', '2850',
#        '28000', '2200', '130000', '1250', '17200', '3100', '2900', '5100',
#        '2050', '107', '12500', '370', '407791', '22500', '52000', '20700',
#        '430000', '1600', '120', '160', '355', '5500', '520', '64', '141',
#        '240', '27000', '7500', '5600', '35', '325000', '34000', '3',
#        '60900', '2600', '750', '6700', '570000', '18000', '375000',
#        '1200000', '465000', '825000', '1100000', '560000', '61', '340000',
#        '125000', '1365', '119500', '66000', '29000', '84000', '69000',
#        '58000', '51000', '140', '6600', '484000', '340', '14500', '17500',
#        '25100', '3200', '65000', '650000', '5750', '3000000', '298',
#        '1500000', '28', '42000', '4700', '56000', '37000', '840', '185',
#        '170', '56', '213', '41000', '193', '106', '613', '128', '335',
#        '3765', '311', '51', '115', '86', '71', '63', '459', '157', '132',
#        '2700', '89', '567', '73', '125', '207', '260', '195', '224', '99',
#        '14059', '1800', '388', '29', '650', '3600', '79', '680', '4360',
#        '850', '82000', '68000', '63000', '27500', '28500', '180000',
#        '510000', '6', '110', '13', '320000', '124000', '32200', '330',
#        '137000', '54', '61000', '465', '10600', '19000', '625000', '161',
#        '138', '5300', '634', '102000', '5800', '4200', '149', '540',
#        '57000', '21000', '33000', '10300', '84', '102', '155', '66',
#        '210', '76', '74', '112', '93000', '52', '7000000', '440', '222',
#        '241', '87', '2300', '3700', '97', '234', '1900', '57', '88',
#        '559'], dtype=object)

# %%
import re

string = '5000s'

def number_cleaner(text):
    return re.findall(r'([-><+]\s*(\d+))&((\d+)[+s])', text)

number_cleaner(string)
# Out:
# []

# %%
protests.dtypes
# Out:
# Year            object
# Country         object
# freedom         object
# Protest_Name    object
# Motivations     object
# Peak_Size       object
# dtype: object

# %%
protests[~protests.Peak_Size.str.contains("unknown")]
# Out:
#        Year           Country      freedom                     Protest_Name  \
# 0      2019           Albania  Partly free         Local elections protests
# 1      2019           Algeria     Not free    Protests against “Le Pouvoir”
# 2      2018         Argentina         Free               Austerity protests
# 3      2020         Argentina         Free  Violence against women protests
# 4      2018           Armenia  Partly free          “#RejectSerzh” protests
# ...     ...               ...          ...                              ...
# 14506  2012  Papua New Guinea  Partly free      political behavior, process
# 14507  2012  Papua New Guinea  Partly free      political behavior, process
# 14508  2013  Papua New Guinea  Partly free      political behavior, process
# 14509  2014  Papua New Guinea  Partly free      political behavior, process
# 14510  2016  Papua New Guinea  Partly free            removal of politician
#
#                                              Motivations Peak_Size
# 0                        Electoral fraud and corruption.        10
# 1      Economic downturn, corruption and nepotism, an...         1
# 2      Rising inflation and unemployment, as well as ...        10
# 3      Violence against women and lack of resources/i...      1000
# 4         Democratic backslide, poverty, and corruption.       100
# ...                                                  ...       ...
# 14506                                                NaN      1000
# 14507                                                NaN      1000
# 14508                                                NaN      2000
# 14509                                                NaN       100
# 14510                                                NaN      1000
#
# [14089 rows x 6 columns]

# %%
protests['Peak_Size'] = protests['Peak_Size'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-3a74806720e0> in <module>
# ----> 1 protests['Peak_Size'] = protests['Peak_Size'].astype(int)
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/Cellar/jupyterlab/2.1.4/libexec/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'unknown'

# %%
# issues:
# the data for the carnegie dataset (years 2017 to 2020) is in different bases
# this happens after applying the number cleaner
## inside the protests column 'Peak_Size' there's an 'unknown' value I do not manage to get rid of
### i cannot turn column into integers, maybe due to the prior points

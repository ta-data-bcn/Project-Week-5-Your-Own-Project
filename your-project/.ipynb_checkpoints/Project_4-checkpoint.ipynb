# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set
# Out:
# <function seaborn.rcmod.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)>

# %%
w_happiness = pd.read_csv('2017.csv')
w_economic = pd.read_csv('economic_freedom_index2019_data.csv',  encoding='latin-1')
w_human = pd.read_csv('hfi_cc_2018.csv')
gdp = pd.read_csv('API_NY.GDP.PCAP.PP.CD_DS2_en_csv_v2_41041.csv', skiprows=3)
gini = pd.read_csv('API_SI.POV.GINI_DS2_en_csv_v2_41010.csv', skiprows=3)

# %%
w_happiness = w_happiness[['Country', 'Happiness.Rank', 'Happiness.Score']]
w_happiness.head(3)
#Y = 2017
# Out:
#    Country  Happiness.Rank  Happiness.Score
# 0   Norway               1            7.537
# 1  Denmark               2            7.522
# 2  Iceland               3            7.504

# %%
w_economic = w_economic[['Country Name','World Rank', 'Unemployment (%)', 'GDP Growth Rate (%)', '2019 Score']].sort_values('World Rank').reset_index(drop = True)
w_economic.head(3)
#Y = 2019
# Out:
#   Country Name  World Rank Unemployment (%)  GDP Growth Rate (%)  2019 Score
# 0    Hong Kong         1.0              3.1                  3.8        90.2
# 1    Singapore         2.0              2.0                  3.6        89.4
# 2  New Zealand         3.0              4.9                  3.0        84.4

# %%
w_human = w_human[['countries', 'hf_rank', 'hf_score',]].loc[w_human['year'] == 2016].sort_values('hf_rank').reset_index(drop = True)
w_human.head(3)
#Y = 2016
# Out:
#      countries  hf_rank  hf_score
# 0  New Zealand      1.0  8.887410
# 1  Switzerland      2.0  8.787759
# 2    Hong Kong      3.0  8.776840

# %%
gdp = gdp[['Country Name', '2018']]
gdp = gdp.dropna()
gdp = gdp.astype({"Country Name": object, "2018": int})
gdp.head(3)
# Out:
#   Country Name   2018
# 1  Afghanistan   1951
# 2       Angola   6440
# 5   Arab World  17557

# %%
gini =gini[['Country Name','2010']]
gini = gini.dropna().reset_index(drop = True)
gini.head(3)
#Y = 2010
# Out:
#   Country Name  2010
# 0    Argentina  43.0
# 1      Armenia  30.0
# 2    Australia  34.7

# %%
merge1 = pd.merge(w_happiness, w_economic, how='left', left_on=['Country'], right_on=['Country Name'])
merge1 = merge1.dropna()
merge1.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score Country Name  World Rank  \
# 0       Norway               1            7.537       Norway        26.0
# 1      Denmark               2            7.522      Denmark        14.0
# 2      Iceland               3            7.504      Iceland        11.0
# 3  Switzerland               4            7.494  Switzerland         4.0
# 4      Finland               5            7.469      Finland        20.0
#
#   Unemployment (%)  GDP Growth Rate (%)  2019 Score
# 0              4.2                  1.8        73.0
# 1              5.7                  2.1        76.7
# 2              2.8                  3.6        77.1
# 3              4.8                  1.1        81.9
# 4              8.6                  3.0        74.9

# %%
merge2 = pd.merge(merge1, w_human, how='left', left_on=['Country Name'], right_on=['countries'])
merge2.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score Country Name  World Rank  \
# 0       Norway               1            7.537       Norway        26.0
# 1      Denmark               2            7.522      Denmark        14.0
# 2      Iceland               3            7.504      Iceland        11.0
# 3  Switzerland               4            7.494  Switzerland         4.0
# 4      Finland               5            7.469      Finland        20.0
#
#   Unemployment (%)  GDP Growth Rate (%)  2019 Score    countries  hf_rank  \
# 0              4.2                  1.8        73.0       Norway     10.0
# 1              5.7                  2.1        76.7      Denmark      6.0
# 2              2.8                  3.6        77.1      Iceland     27.0
# 3              4.8                  1.1        81.9  Switzerland      2.0
# 4              8.6                  3.0        74.9      Finland     10.0
#
#    hf_score
# 0  8.471241
# 1  8.547820
# 2  8.151753
# 3  8.787759
# 4  8.472184

# %%
merge3 = pd.merge(merge2, gdp, how='left', left_on=['Country Name'], right_on=['Country Name'])
merge3 = merge3.dropna().drop('Country', axis = 1)
merge3.head()
# Out:
#    Happiness.Rank  Happiness.Score Country Name  World Rank Unemployment (%)  \
# 0               1            7.537       Norway        26.0              4.2
# 1               2            7.522      Denmark        14.0              5.7
# 2               3            7.504      Iceland        11.0              2.8
# 3               4            7.494  Switzerland         4.0              4.8
# 4               5            7.469      Finland        20.0              8.6
#
#    GDP Growth Rate (%)  2019 Score    countries  hf_rank  hf_score     2018
# 0                  1.8        73.0       Norway     10.0  8.471241  63756.0
# 1                  2.1        76.7      Denmark      6.0  8.547820  56120.0
# 2                  3.6        77.1      Iceland     27.0  8.151753  57597.0
# 3                  1.1        81.9  Switzerland      2.0  8.787759  68943.0
# 4                  3.0        74.9      Finland     10.0  8.472184  48635.0

# %%
final_tab = pd.merge(merge3, gini, how='left', left_on=['Country Name'], right_on=['Country Name'])
final_tab = final_tab.rename(columns={"Country Name": "country", "2010": "gini", "2018": "gdp_ppp","Happiness.Rank": "h_rank","Happiness.Score": "h_score","World Rank": "ef_rank", "GDP Growth Rate (%)": "growth_rate", "Unemployment (%)": "unemployment", '2019 Score':'ef_score'})
final_tab = final_tab.drop('countries', axis = 1)

# %%
final_tab = final_tab[['country', 'h_rank', 'hf_rank', 'ef_rank', 'h_score', 'ef_score', 'hf_score',
       'gini', 'unemployment', 'growth_rate', 'gdp_ppp']]
final_tab = final_tab.dropna().reset_index(drop = True)
final_tab['ef_score'] = final_tab['ef_score']/10
final_tab.sort_values('ef_rank')
# Out:
#            country  h_rank  hf_rank  ef_rank  h_score  ef_score  hf_score  \
# 3      Switzerland       4      2.0      4.0    7.494      8.19  8.787759
# 8        Australia      10      4.0      5.0    7.284      8.09  8.582219
# 13         Ireland      15      8.0      6.0    6.977      8.05  8.504565
# 17  United Kingdom      19      8.0      7.0    6.714      7.89  8.497918
# 6           Canada       7      5.0      8.0    7.316      7.77  8.565863
# 2          Iceland       3     27.0     11.0    7.504      7.71  8.151753
# 12   United States      14     17.0     12.0    6.993      7.68  8.388655
# 5      Netherlands       6      6.0     13.0    7.377      7.68  8.554421
# 1          Denmark       2      6.0     14.0    7.522      7.67  8.547820
# 34         Estonia      66     14.0     15.0    5.611      7.66  8.436851
# 55         Georgia     125     40.0     16.0    4.286      7.59  7.798268
# 16      Luxembourg      18     15.0     17.0    6.863      7.59  8.428701

#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow0_col7 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow0_col8 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col0 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col2 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col3 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col4 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col6 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col7 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col0 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col1 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col5 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col6 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col7 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow2_col8 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col1 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col4 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col5 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col6 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col7 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow3_col8 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col3 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col5 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col6 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col7 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow4_col8 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col0 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col2 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col3 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col4 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col6 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow5_col8 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow6_col0 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow6_col1 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow6_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow6_col3 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow6_col4 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_330392d0_b539_11e9_948e_2df75accc72drow6_col5 {
#             background-color:  #a7c5fe;
#             color:  #000000;

# %%
final_tab.to_csv("final_tab.csv")
final_tab.columns
# Out:
# Index(['country', 'h_rank', 'hf_rank', 'ef_rank', 'h_score', 'ef_score',
#        'hf_score', 'gini', 'unemployment', 'growth_rate', 'gdp_ppp'],
#       dtype='object')

# %%
work = pd.read_csv('/home/javier/Documents/ironhack_projects/final_tab.csv')[['country', 'h_score', 'ef_score',
       'hf_score', 'gini', 'unemployment', 'gdp_ppp']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-328820655194> in <module>
# ----> 1 work = pd.read_csv('/home/javier/Documents/ironhack_projects/final_tab.csv')[['country', 'h_score', 'ef_score',
#       2        'hf_score', 'gini', 'unemployment', 'gdp_ppp']]
#
# ~/anaconda3/envs/iron/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/envs/iron/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/envs/iron/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/envs/iron/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/envs/iron/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/home/javier/Documents/ironhack_projects/final_tab.csv' does not exist: b'/home/javier/Documents/ironhack_projects/final_tab.csv'

# %%
work

# %%
corr = work.corr()
corr.style.background_gradient(cmap='coolwarm')

# %%
sns.set(style="ticks")
plt.figure(figsize=(8, 6))
sns.heatmap(work.corr(), annot=True, fmt=".2f")
plt.show()

# %%
sns.set()
plt.figure(figsize=(20, 15))
sns.regplot("gdp_ppp", "gini", data=work, color="k", label='Gini index')

plt.show()

# %%
plt.figure(figsize = (16,12))
sns.regplot("gdp_ppp", "h_score", data=work, color="g", label = 'Happiness')
#sns.regplot("gdp_ppp", "hf_score", data=work, color="c", label = 'Social freedom', scatter = False)
#sns.regplot("gdp_ppp", "ef_score", data=work, color="r", label = 'Economic Freedom', scatter = False)

plt.show()

# %%
f, ax = plt.subplots(figsize = (16,12))
ax.set(xlim=(0, 120000), ylim=(5, 10))
sns.regplot("gdp_ppp", "h_score", data=work, color="g", label = 'Happiness', scatter=False)
sns.regplot("gdp_ppp", "hf_score", data=work, color="c", label = 'Social freedom', scatter = False)
sns.regplot("gdp_ppp", "ef_score", data=work, color="r", label = 'Economic Freedom', scatter = False)

# %%
sns.set()
plt.figure(figsize=(16, 12))
#sns.regplot("h_score", "h_score", data=work, color="m", label = 'Happiness')
sns.regplot("h_score", "hf_score", data=work, color="c", label = 'Social freedom')
sns.regplot("h_score", "ef_score", data=work, color="red", label = 'Economic Freedom')
plt.legend()
plt.show()

# %%
sns.set()
plt.figure(figsize=(16, 12))
sns.regplot("ef_score", "h_score", data=work, color="g", label = 'Happiness')
sns.regplot("ef_score", "hf_score", data=work, color="c", label = 'Social freedom')
#sns.regplot("ef_score", "ef_score", data=work, color="r", label = 'Economic Freedom')
plt.legend()
plt.show()

# %%
sns.set()
plt.figure(figsize=(16, 12))
sns.regplot("hf_score", "h_score", data=work, color="g",  label = 'Happiness')
#sns.regplot("hf_score", "hf_score", data=work, color="darkcyan", label = 'Social freedom')
sns.regplot("hf_score", "ef_score", data=work, color="red", label = 'Economic Freedom')
plt.legend()
plt.show()

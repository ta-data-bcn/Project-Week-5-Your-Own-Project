# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from requests import get
import re

# %%
# Scraping web FBREF.com
url = 'https://fbref.com/en/comps/22/Major-League-Soccer-Stats#stats_standard_squads::none'
html = requests.get(url).text
html_soup = BeautifulSoup(html, 'html.parser')
print(html_soup.prettify())
pretty_soup = html_soup.prettify()
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/fb/www/base" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202004286" rel="dns-prefetch"/>
#    <!-- no:cookie fast load the css.           -->
#    <script>
#     function gup(n) {n = n.replace(/[\[]/, '\\[').replace(/[\]]/, '\\]'); var r = new RegExp('[\\?&]'+n+'=([^&#]*)'); var re = r.exec(location.search);   return re === null?'':decodeURIComponent(re[1].replace(/\+/g,' '));}; document.srdev = gup('srdev')
#    </script>
#    <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#    <link crossorigin="" href="https://d6rt22vwfyr3i.cloudfront.net" rel="preconnect"/>
#    <style>
# ...

# %%
# Soup scraping 

MLS_2020_General_Stats = html_soup.find_all('div', class_='overthrow table_container')
MLS_2020_General_Stats
# Out:
# [<div class="overthrow table_container" id="div_results100901Eastern-Conference_overall">
#  <table class="min_width sortable stats_table" data-cols-to-freeze="2,2" id="results100901Eastern-Conference_overall"><caption>Eastern Conference Table</caption>
#  <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
#  <thead>
#  <tr>
#  <th aria-label="Squad finish in competition" class="poptip sort_default_asc center" data-stat="rank" data-tip="&lt;strong&gt;Squad finish in competition&lt;/strong&gt;&lt;br&gt;Finish within the league or competition.&lt;br&gt;For knockout competitions may show final round reached.&lt;br&gt;Colors and arrows represent promotion/relegation or qualifiation for continental cups.&lt;br&gt;Trophy indicates team won league whether by playoffs or by leading the table.&lt;br&gt;Star indicates topped table in league USING another means of naming champion." scope="col">Rk</th>
# ...

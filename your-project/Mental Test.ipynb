# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Reading Data

# %%
mentest=pd.read_excel('/Users/islaam/Documents/DATA_SCIENCE/DATA_ANALYSIS/IRONHACK/Project-Week-5-Your-Own-Project/Data/fixed data.xlsx', sheet_name='summary')

# %% [markdown]
# # Cleaning and Organizing Data

# %%
mentest.columns = mentest.iloc[0]

# %%
mentest.drop(0, inplace=True)

# %%
mentest = mentest.loc[:, :'attitudes toward music as a coping strategy']

# %%
stress_level=mentest.groupby(['stress level']).count()

# %%
music_response=mentest.groupby(['attitudes toward music as a coping strategy']).count()

# %%
stress_level.reset_index(inplace=True)

# %%
music_response.reset_index(inplace=True)

# %%
music_response.drop(columns=['stress level'],inplace=True)

# %%
stress_level.rename(columns={'stress level':'stress level' , 'respondent':'respondents'},inplace=True)

# %%
stress_level.drop(columns=['attitudes toward music as a coping strategy'],inplace=True)

# %%
stress_level.columns
# Out:
# Index(['stress level', 'resopondent'], dtype='object', name=0)

# %%
stress_level.sort_values(by=['resopondent'],ascending=False,inplace=True)
stress_level
# Out:
# 0  stress level  resopondent
# 5          2.50           10
# 6          2.75            8
# 3          2.00            8
# 4          2.25            7
# 7          3.00            5
# 8          3.25            4
# 1          1.50            4
# 2          1.75            3
# 0          0.75            1

# %%
sns.barplot(y='resopondent',x='stress level',data=stress_level)

# %%
music_response.sort_values(by=['resopondent'],ascending=False,inplace=True)

# %%
sns.barplot(y='resopondent',x='attitudes toward music as a coping strategy',data=music_response)

# %%
sns.set(rc={'figure.figsize':(15,10)})

# %%
sns.barplot(x='resopondent',y='stress level',data=mentest)

# %%
sns.barplot(x='resopondent',y='attitudes toward music as a coping strategy',data=mentest)

# %%
sns.barplot(x='stress level',y='resopondent',data=stress_level)

# %%
sns.barplot(x='attitudes toward music as a coping strategy',y='resopondent',data=music_response)

# %% [markdown]
# # Try 1

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://www.cbinsights.com/research-unicorn-companies'

# %%
page = requests.get(url)
content = page.content

# %%
soup = BeautifulSoup('<html><body>content</body></html>')

# %%
soup = BeautifulSoup(content, 'html.parser')
print(soup)
# Unicorn_Tracker = soup.find(id='element-32')
# type(Unicorn_Tracker)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="" name="iy453p9485yheisruhs5"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <title>The Complete List of Unicorn Companies</title>
# <meta content="A unicorn company is a startup with a valuation over $1 billion. This is an ongoing list of all unicorn companies in the US and abroad.  " name="description"/>
# <meta content="unicorn companies,billion dollar startups,unicorn startups" name="keywords"/>
# <link href="https://www.cbinsights.com/research-unicorn-companies" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="The Complete List of Unicorn Companies" property="og:title"/>
# <meta content="Meet all of the world's startups valued at $1B+ in our ongoing list of all unicorn companies in the US and abroad.  " property="og:description"/>
# ...

# %%
soup.find_all('table')
# Out:
# [<table class="sortable-theme-bootstrap" data-sortable="">
#  <thead>
#  <tr>
#  <th>Company</th>
#  <th data-sorted="true" width="120">Valuation ($B)</th>
#  <th>Date Joined</th>
#  <th>Country</th>
#  <th>Industry</th>
#  <th data-sortable="false">Select Investors</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td><a href="https://www.cbinsights.com/company/bytedance">Toutiao (Bytedance)</a></td>
#  <td data-value="75">$75</td>
#  <td>4/7/2017</td>
#  <td>China</td>
#  <td>Artificial intelligence</td>
#  <td>Sequoia Capital China, SIG Asia Investments, Sina Weibo, Softbank Group</td>
#  </tr>
#  <tr>1.
#  	  <td><a href="https://www.cbinsights.com/company/didi-kuaidi">Didi Chuxing
#  	  </a></td>
#  <td data-value="56">$56</td>
#  <td>12/31/2014</td>
#  <td>China</td>
#  <td>Auto &amp; transportation</td>
#  <td>Matrix Partners, Tiger
#  	  Global Management, Softbank Corp.,</td>
#  </tr>
#  <tr>
#  <td><a href="https://www.cbinsights.com/company/stripe">Stripe</a></td>
# ...

# %%
result = Unicorn_Tracker.select('tbody tr')

Company Names = [elem.find_all('td')[0].getText() for elem in result]
summary
# Out:
#   File "<ipython-input-6-d5f116762122>", line 3
#     Company Names = [elem.find_all('td')[0].getText() for elem in result]
#                 ^
# SyntaxError: invalid syntax

# %%
'''page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')
weather_2weeks = soup.find(id='wt-ext')
table_rows= weather_2weeks.select('table tbody tr')

for elem in table_rows: # we expect all rows
    temp_string = elem.find_all('td')[1].getText()
    print(temp_string)'''
# Out:
# "page = requests.get(url)\n\nsoup = BeautifulSoup(page.content, 'html.parser')\nweather_2weeks = soup.find(id='wt-ext')\ntable_rows= weather_2weeks.select('table tbody tr')\n\nfor elem in table_rows: # we expect all rows\n    temp_string = elem.find_all('td')[1].getText()\n    print(temp_string)"

# %%
html_string = Unicorn_Tracker.prettify()

# %%
dfs = pd.read_html(html_string)
df = dfs[0]
df
# Out:
#                 Company Valuation ($B) Date Joined        Country  \
# 0   Toutiao (Bytedance)            $75    4/7/2017          China
# 1          Didi Chuxing            $56  12/31/2014          China
# 2                Stripe            $36   1/23/2014  United States
# 3                SpaceX          $33.3   12/1/2012  United States
# 4                Airbnb            $18   7/26/2011  United States
# ..                  ...            ...         ...            ...
# 72      Face++ (Megvii)             $4  10/31/2017          China
# 73               Roblox             $4    9/4/2018  United States
# 74     Impossible Foods             $4   5/13/2019  United States
# 75          TripActions             $4   11/8/2018  United States
# 76         XPeng Motors             $4    8/2/2018          China
#
#                         Industry  \
# 0        Artificial intelligence
# 1          Auto & transportation
# 2                        Fintech
# 3                          Other
# ...

# %%
df.to_csv(r'data/cbinsights_unicorntracker.csv')

# %%
##

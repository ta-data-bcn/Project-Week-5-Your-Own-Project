# %% [markdown]
# # Is it worth it? - Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
df_bike = pd.read_csv("/home/pau/Ironhack/week5/project5/Project-Week-5-Your-Own-Project/your-project/date_usertype_tripduration.csv")

# %%
df_bike
# Out:
#     YearMonthDay  usertype  tripduration
# 0     2014-10-13       818    237.284833
# 1     2014-10-14       982    306.103728
# 2     2014-10-15       626    133.439650
# 3     2014-10-16       790    222.390892
# 4     2014-10-17       588    149.370242
# 5     2014-10-18       798    325.786612
# 6     2014-10-19      1332    684.871028
# 7     2014-10-20       778    206.561264
# 8     2014-10-21       714    177.494541
# 9     2014-10-22       282     63.867778
# 10    2014-10-23       676    171.934122
# 11    2014-10-24       860    240.542347
# 12    2014-10-25       432    133.030439
# 13    2014-10-26       504    172.843146
# 14    2014-10-27       734    182.226487
# 15    2014-10-28       470    125.498221
# 16    2014-10-29       880    195.342234
# 17    2014-10-30       454     82.033006
# 18    2014-10-31       452     88.225944
# 19    2014-11-01       876    331.383929
# 20    2014-11-02       662    255.298751
# 21    2014-11-03       474     83.938616
# ...

# %%
df_bike[["tripduration"]].mean()/500
# Out:
# tripduration    0.272553
# dtype: float64

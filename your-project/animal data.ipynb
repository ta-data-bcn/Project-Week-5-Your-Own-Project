# %%
import pandas as pd

# %%
animals = pd.read_csv('data/anage_data.csv', sep=';')

# %%
animals.head()
# Out:
#    HAGRID   Kingdom      Phylum         Class        Order         Family  \
# 0       3  Animalia  Arthropoda  Branchiopoda  Diplostraca     Daphniidae
# 1       5  Animalia  Arthropoda       Insecta      Diptera  Drosophilidae
# 2       6  Animalia  Arthropoda       Insecta  Hymenoptera         Apidae
# 3       8  Animalia  Arthropoda       Insecta  Hymenoptera     Formicidae
# 4       9  Animalia  Arthropoda       Insecta  Hymenoptera     Formicidae
#
#            Genus       Species              Common name  \
# 0        Daphnia     pulicaria                  Daphnia
# 1     Drosophila  melanogaster                Fruit fly
# 2           Apis     mellifera                Honey bee
# 3  Cardiocondyla     obscurior  Cardiocondyla obscurior
# 4         Lasius         niger         Black garden ant
#
#    Female maturity (days)  ...  Source  Specimen origin  Sample size  \
# 0                     NaN  ...     NaN          unknown       medium
# ...

# %%
# Only the turtles

animals[animals['Order']== 'Testudines']
# Out:
#       HAGRID   Kingdom    Phylum     Class       Order            Family  \
# 3282    3301  Animalia  Chordata  Reptilia  Testudines  Carettochelyidae
# 3283    3302  Animalia  Chordata  Reptilia  Testudines          Chelidae
# 3284    3303  Animalia  Chordata  Reptilia  Testudines          Chelidae
# 3285    3304  Animalia  Chordata  Reptilia  Testudines          Chelidae
# 3286    3305  Animalia  Chordata  Reptilia  Testudines          Chelidae
# ...      ...       ...       ...       ...         ...               ...
# 3398    3417  Animalia  Chordata  Reptilia  Testudines      Trionychidae
# 3399    3418  Animalia  Chordata  Reptilia  Testudines      Trionychidae
# 3400    3419  Animalia  Chordata  Reptilia  Testudines      Trionychidae
# 3401    3420  Animalia  Chordata  Reptilia  Testudines      Trionychidae
# 3402    3421  Animalia  Chordata  Reptilia  Testudines      Trionychidae
#
#               Genus        Species                          Common name  \
# ...

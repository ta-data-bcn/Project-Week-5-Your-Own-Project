# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('country-and-continent-codes-list-csv.csv')

# %%
df.head()
# Out:
#   Continent_Name Continent_Code                                  Country_Name  \
# 0           Asia             AS              Afghanistan, Islamic Republic of
# 1         Europe             EU                          Albania, Republic of
# 2     Antarctica             AN  Antarctica (the territory South of 60 deg S)
# 3         Africa             AF      Algeria, People's Democratic Republic of
# 4        Oceania             OC                                American Samoa
#
#   Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number
# 0                      AF                       AFG             4.0
# 1                      AL                       ALB             8.0
# 2                      AQ                       ATA            10.0
# 3                      DZ                       DZA            12.0
# 4                      AS                       ASM            16.0

# %%
df.drop(['Continent_Code','Country_Name','Two_Letter_Country_Code','Country_Number'], axis = 1, inplace = True)

# %%
df.rename(columns={"Continent_Name": "Continent","Three_Letter_Country_Code":"Code"})
# Out:
#          Continent Code
# 0             Asia  AFG
# 1           Europe  ALB
# 2       Antarctica  ATA
# 3           Africa  DZA
# 4          Oceania  ASM
# 5           Europe  AND
# 6           Africa  AGO
# 7    North America  ATG
# 8           Europe  AZE
# 9             Asia  AZE
# 10   South America  ARG
# 11         Oceania  AUS
# 12          Europe  AUT
# 13   North America  BHS
# 14            Asia  BHR
# 15            Asia  BGD
# 16          Europe  ARM
# 17            Asia  ARM
# 18   North America  BRB
# 19          Europe  BEL
# 20   North America  BMU
# 21            Asia  BTN
# 22   South America  BOL
# 23          Europe  BIH
# 24          Africa  BWA
# 25      Antarctica  BVT
# 26   South America  BRA
# 27   North America  BLZ
# 28            Asia  IOT
# 29         Oceania  SLB
# ..             ...  ...
# 232           Asia  ARE
# 233         Africa  TUN
# 234         Europe  TUR
# 235           Asia  TUR
# 236           Asia  TKM
# 237  North America  TCA
# ...

# %%
df.to_csv("../data/continents_countries.csv")

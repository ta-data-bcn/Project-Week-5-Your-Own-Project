# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('../data/sales-of-cigarettes-per-adult-per-day.csv')

# %%
df
# Out:
#           Entity      Code  Year  \
# 0        Armenia       ARM  1988
# 1        Armenia       ARM  1989
# 2        Armenia       ARM  1990
# 3        Armenia       ARM  1991
# 4        Armenia       ARM  1992
# 5        Armenia       ARM  1993
# 6        Armenia       ARM  1994
# 7        Armenia       ARM  1995
# 8        Armenia       ARM  1996
# 9        Armenia       ARM  1997
# 10       Armenia       ARM  1998
# 11     Australia       AUS  1920
# 12     Australia       AUS  1921
# 13     Australia       AUS  1922
# 14     Australia       AUS  1923
# 15     Australia       AUS  1924
# 16     Australia       AUS  1925
# 17     Australia       AUS  1926
# 18     Australia       AUS  1927
# 19     Australia       AUS  1928
# 20     Australia       AUS  1929
# 21     Australia       AUS  1930
# 22     Australia       AUS  1931
# 23     Australia       AUS  1932
# 24     Australia       AUS  1933
# 25     Australia       AUS  1934
# 26     Australia       AUS  1935
# ...

# %%
df.columns = ['Country', 'Code','Year','Cig_sold_per_adult_per_day']

# %%
df.head()
# Out:
#    Country Code  Year  Cig_sold_per_adult_per_day
# 0  Armenia  ARM  1988                        12.0
# 1  Armenia  ARM  1989                        11.6
# 2  Armenia  ARM  1990                        11.9
# 3  Armenia  ARM  1991                         9.3
# 4  Armenia  ARM  1992                         4.9

# %%
df = df.loc[df.Year>=1990].copy()

# %%
df.head()
# Out:
#    Country Code  Year  Cig_sold_per_adult_per_day
# 2  Armenia  ARM  1990                        11.9
# 3  Armenia  ARM  1991                         9.3
# 4  Armenia  ARM  1992                         4.9
# 5  Armenia  ARM  1993                         5.5
# 6  Armenia  ARM  1994                         5.7

# %%
#df.drop(['Code'], axis = 1, inplace = True)

# %%
df.head(10)
# Out:
#       Country Code  Year  Cig_sold_per_adult_per_day
# 2     Armenia  ARM  1990                        11.9
# 3     Armenia  ARM  1991                         9.3
# 4     Armenia  ARM  1992                         4.9
# 5     Armenia  ARM  1993                         5.5
# 6     Armenia  ARM  1994                         5.7
# 7     Armenia  ARM  1995                         5.6
# 8     Armenia  ARM  1996                         5.6
# 9     Armenia  ARM  1997                         5.6
# 10    Armenia  ARM  1998                         5.7
# 81  Australia  AUS  1990                         7.6

# %%
df1 = df.pivot_table(index=['Country','Code'],values=['Cig_sold_per_adult_per_day','Year'],aggfunc={'Cig_sold_per_adult_per_day':np.mean,'Year':'count'}).copy()

# %%
df1.head()
# Out:
#                  Cig_sold_per_adult_per_day  Year
# Country    Code
# Armenia    ARM                     6.644444     9
# Australia  AUS                     5.257143    21
# Austria    AUT                     5.800000    15
# Azerbaijan AZE                     3.444444     9
# Belarus    BLR                     4.844444     9

# %%
df1.to_csv("../data/cigs.csv")

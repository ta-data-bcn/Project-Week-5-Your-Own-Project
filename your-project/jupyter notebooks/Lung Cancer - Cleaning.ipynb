# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('../data/cancer-death-rates-by-type.csv')

# %%
df
# Out:
#            Entity Code  Year  Prostate cancer (per 100,000)  \
# 0     Afghanistan  AFG  1990                       5.831800
# 1     Afghanistan  AFG  1991                       5.887376
# 2     Afghanistan  AFG  1992                       5.963580
# 3     Afghanistan  AFG  1993                       6.053233
# 4     Afghanistan  AFG  1994                       6.130208
# 5     Afghanistan  AFG  1995                       6.181237
# 6     Afghanistan  AFG  1996                       6.222203
# 7     Afghanistan  AFG  1997                       6.262193
# 8     Afghanistan  AFG  1998                       6.293969
# 9     Afghanistan  AFG  1999                       6.336251
# 10    Afghanistan  AFG  2000                       6.362276
# 11    Afghanistan  AFG  2001                       6.404388
# 12    Afghanistan  AFG  2002                       6.436136
# 13    Afghanistan  AFG  2003                       6.459081
# 14    Afghanistan  AFG  2004                       6.479068
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 25 columns):
# Entity                                                6468 non-null object
# Code                                                  5488 non-null object
# Year                                                  6468 non-null int64
# Prostate cancer (per 100,000)                         6468 non-null float64
# Breast cancer (per 100,000)                           6468 non-null float64
# Pancreatic cancer (per 100,000)                       6468 non-null float64
# Brain and nervous system cancer (per 100,000)         6468 non-null float64
# Lip and oral cavity cancer (per 100,000)              6468 non-null float64
# Colon and rectum cancer (per 100,000)                 6468 non-null float64
# Gallbladder and biliary tract cancer (per 100,000)    6468 non-null float64
# Liver cancer (per 100,000)                            6468 non-null float64
# ...

# %%
df.describe()
# Out:
#               Year  Prostate cancer (per 100,000)  \
# count  6468.000000                    6468.000000
# mean   2003.500000                       9.239241
# std       8.078372                       5.787221
# min    1990.000000                       2.335936
# 25%    1996.750000                       5.083489
# 50%    2003.500000                       8.086822
# 75%    2010.250000                      11.168940
# max    2017.000000                      39.687160
#
#        Breast cancer (per 100,000)  Pancreatic cancer (per 100,000)  \
# count                  6468.000000                      6468.000000
# mean                      9.356832                         5.073092
# std                       3.197232                         2.584046
# min                       2.531681                         1.313990
# 25%                       6.800647                         3.013801
# 50%                       9.040351                         4.337424
# ...

# %%
#df['Year'].value_counts() = 28 years

# %%
#employees.pivot_table(values=['Salary', 'Name'], index=['Department', 'Title'], aggfunc={'Salary': np.mean, 'Department': 'count'})

# %%
df.head()
# Out:
#         Entity Code  Year  Prostate cancer (per 100,000)  \
# 0  Afghanistan  AFG  1990                       5.831800
# 1  Afghanistan  AFG  1991                       5.887376
# 2  Afghanistan  AFG  1992                       5.963580
# 3  Afghanistan  AFG  1993                       6.053233
# 4  Afghanistan  AFG  1994                       6.130208
#
#    Breast cancer (per 100,000)  Pancreatic cancer (per 100,000)  \
# 0                     7.624524                         2.242167
# 1                     7.663767                         2.228419
# 2                     7.773940                         2.218351
# 3                     7.938782                         2.213309
# 4                     8.089540                         2.209294
#
#    Brain and nervous system cancer (per 100,000)  \
# 0                                       5.079117
# 1                                       5.053449
# 2                                       4.998421
# ...

# %%
df.rename(columns={'Tracheal, bronchus, and lung cancer (per 100,000)':'Lung cancer (per 100,000)'},inplace=True)

# %%
df.head(3)
# Out:
#         Entity Code  Year  Prostate cancer (per 100,000)  \
# 0  Afghanistan  AFG  1990                       5.831800
# 1  Afghanistan  AFG  1991                       5.887376
# 2  Afghanistan  AFG  1992                       5.963580
#
#    Breast cancer (per 100,000)  Pancreatic cancer (per 100,000)  \
# 0                     7.624524                         2.242167
# 1                     7.663767                         2.228419
# 2                     7.773940                         2.218351
#
#    Brain and nervous system cancer (per 100,000)  \
# 0                                       5.079117
# 1                                       5.053449
# 2                                       4.998421
#
#    Lip and oral cavity cancer (per 100,000)  \
# 0                                  1.380588
# 1                                  1.388183
# 2                                  1.398741
#
#    Colon and rectum cancer (per 100,000)  \
# 0                              10.153677
# ...

# %%
df1 = df.pivot_table(values=['Lung cancer (per 100,000)'], index=['Entity','Code'],aggfunc={'Lung cancer (per 100,000)':np.mean}).copy()

# %%
df1.index.names = ['Country','Code']
df1.head()
# Out:
#                      Lung cancer (per 100,000)
# Country        Code
# Afghanistan    AFG                   13.063858
# Albania        ALB                   24.118825
# Algeria        DZA                    9.365556
# American Samoa ASM                   25.845224
# Andorra        AND                   29.440286

# %%
df1.head()
# Out:
#                      Lung cancer (per 100,000)
# Country        Code
# Afghanistan    AFG                   13.063858
# Albania        ALB                   24.118825
# Algeria        DZA                    9.365556
# American Samoa ASM                   25.845224
# Andorra        AND                   29.440286

# %%
df1.to_csv("./data/lung_cancer.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-e568522d6c40> in <module>
# ----> 1 df1.to_csv("./data/lung_cancer.csv")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
# ...

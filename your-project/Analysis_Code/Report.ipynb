# %% [markdown]
# # Report

# %% [markdown]
# ## Insights on Collaborations

# %% [markdown]
# The units of this analysis will be dollars for the prices and points in the Google Trends Index, which goes from 0 meaning not enough data, to a 100 meaning maximum popularity of a search term relative all others.

# %% [markdown]
# ### Basic Decription

# %% [markdown]
# On the distribution and basic statistical analysis of these measures we have the following:
#
# - Michael Jordan & the Air Jordan 1 Chicago:

# %% [markdown]
# ![Michael_hist.JPG](attachment:Michael_hist.JPG)
# ![Jordan1_Chicago_hist.JPG](attachment:Jordan1_Chicago_hist.JPG)

# %% [markdown]
# With means and standard deviations of (respectively):
# ![MJ_avg.JPG](attachment:MJ_avg.JPG)![MJ_stdv.JPG](attachment:MJ_stdv.JPG)

# %% [markdown]
# **Please note**: The first number for standard deviation is for the trend and the second for the prices

# %% [markdown]
# So we see that Michael's popularity is around 25 points in average and a standard deviation of 21.9
#
# The sneakers price averages at a 1000$ with a volatily close to 318. The diferent spikes and the separated distributions might indicate different price-levels for different sizes, however we do not have data on them at the moment. Retail price was 160

# %% [markdown]
# - Travis Scott & the Air Jordan 1 Cactus Jack
# ![Travis_hist.JPG](attachment:Travis_hist.JPG)
# ![Jordan1_Travis_hist.JPG](attachment:Jordan1_Travis_hist.JPG)

# %% [markdown]
# With means and standard deviations of (respectively):
#
# ![TS_avg.JPG](attachment:TS_avg.JPG)
# ![TS_stdv.JPG](attachment:TS_stdv.JPG)

# %% [markdown]
# Travis' popularity is way lower at about 9.18, which is not surprising given the fact that it is a figure most known in the hip hop culture and mainly since 2015, whose impact is limited to young people, unlike Michael, which has been an cultural staple for longer than 20 years, it is also less volatile  given the dedicated and active fanbase, which contrast with the peaks in popularity of a retired player like Jordan.
#
# The price of the sneaker averages at 1324.6$ which is almost 1 standard deviation over the Chicago colorway and is a good indicator of how even being the same model, the sense of exclusivity plays a big part in the market value (this colorway has been released in a more limited amount and only once), it is less volatile though, given the consistent sense of exclusivity. Retail price was 175.

# %% [markdown]
# - Kanye West & the Air Yeezy 2 Red October
# ![Kanye_hist.JPG](attachment:Kanye_hist.JPG)
# ![Yeexy_RedOctober_hist.JPG](attachment:Yeexy_RedOctober_hist.JPG)

# %% [markdown]
# With means and standard deviations of (respectively):
#
# ![KW_avg.JPG](attachment:KW_avg.JPG)
# ![KW_stdv.JPG](attachment:KW_stdv.JPG)

# %% [markdown]
# The popularity average we observe for Kanye West is a bit higher than that for Travis, even though he has been a promiment figure for longer, especially in the US since 2004, and has in recent years become a mainstream figure even internationally. However we see it is a bit more volatile than Travis' popularity, given the fact that what triggers searches about him are probably his often extravagant and controversial declarations.
#
# The Red Octobers average at a price of 6322.57$ with an ashtounding volatily of 1637.3 dollars. retail price was 250
# This is explained partially by the fact this shoe will never be re-stocked again, given the end of the contractual relationship between Nike and Kanye and his subsequent partnership with the competitor brand, adidas. The high volatilty could be explained by the collector's value of the shoe and how much demand there is for it, since supply is perfectly inelastic for this one, thus variations in price depend on demand.

# %% [markdown]
# - Virgil Abloh & the Nike X OFF-WHITE Presto 'The Ten'
# ![Virgil_hist.JPG](attachment:Virgil_hist.JPG)
# ![OFFWHITE_Presto_hist.JPG](attachment:OFFWHITE_Presto_hist.JPG)

# %% [markdown]
# With means and standard deviations of (respectively):
#
# ![VA_avg.JPG](attachment:VA_avg.JPG)
# ![VA_stdv.JPG](attachment:VA_stdv.JPG)

# %% [markdown]
# Virgil Abloh is surprisingly a bit more popular or at least searched than Travis or Kanye, but still only half as much as Michael, this might be because of the wide appeal of his body of work. He is a designer, architect, DJ and general creator, which makes him cater to a wider audience, ranging from streetwear hypebeasts and teenagers to older creative professionals. His volatilty is almost equal to his popularity, which means on ocassions he doubles his popularity and gets to Michael's level, with some degree of overlap and other times can  it get close to 0.
#
# The sneakers average price is 1843.9$ and avolatility of 247. It is almost 3 standard deviations over the Chicagos and this is probably given by the fact the collection to which this model belongs, was not only the most impactful thing to happen that year (2017) in the streetwear industry, but also the begining of the most succesful ongoing collaboration between an independent brand and Nike, that still releases new models (the latest being last week). The volatilty is lower than the Chicagos which could signal, as with the Cactus Jack's a more stable preception of exclusivity. Retail price was 160.

# %% [markdown]
# ### Comparison and relation between popularity and price

# %% [markdown]
# The most popular collaborator on average is Michael Jordan an the most expensive sneaker is the Air Yeezy 2 Red October, both of them also have the highest standard deviations. These two are also the two with the highest correlation between popularity and price.

# %% [markdown]
# ![Jordan_corr.JPG](attachment:Jordan_corr.JPG)
# ![Kanye_corr.JPG](attachment:Kanye_corr.JPG)
# ![Travis_corr.JPG](attachment:Travis_corr.JPG)
# ![Virgil_corr.JPG](attachment:Virgil_corr.JPG)

# %% [markdown]
# So we can affirm that Michael Jordan's popularity has the most effect on the price of his signature sneaker, and a positive one, in comparison to that of other younger, newer figures, even though the pricing of his sneaker on reselling is the lowest among them.
#
# The second most correlated celebrity is Kanye West, this time negatively, which would make sense given the fact that tipically the headlines he makes are quite negative, which would mean people have less of an incentive to be associated with him and prices would fall down because of a demand drop.
#
# Both Travis and Virgil's popularity seem to have less of an impact on the pricing of their sneaker on the resell market. However there's the caveat that there are considerations outside the scope of this paper that might lead to this watered down relation, such as the relationship not being linear or there being a lag between the searches and it's  reflection on the price. There is also the fact that there are other, probably stronger variables that would explain the changes in price, and future revisions of this project will touch on topics like, size, availability and media exposure of the product (instagram posts, youtube videos, product placement, etc...)

# %% [markdown]
# #### Linear Regressions

# %% [markdown]
#  **Michael Jordan**
#  *slope, intercept*
# ![AJMJ_regr.JPG](attachment:AJMJ_regr.JPG)
# ![AJMJ_regr1.JPG](attachment:AJMJ_regr1.JPG)

# %% [markdown]
# **Kanye West**
# ![KW_regr.JPG](attachment:KW_regr.JPG)
# ![KW_regr1.JPG](attachment:KW_regr1.JPG)

# %% [markdown]
# **Travis Scott**
# ![TS_regr.JPG](attachment:TS_regr.JPG)
# ![Ts_regr1.JPG](attachment:Ts_regr1.JPG)

# %% [markdown]
# **Virgil Abloh**
# ![VA_regr.JPG](attachment:VA_regr.JPG)
# ![VA_regr1.JPG](attachment:VA_regr1.JPG)

# %% [markdown]
# We see the linear regressions only make sense for Michael and Kanye, and only marginally for this last one, suggesting that only the highest drops in price have to do with his popularity increasing, thus the greatest scandals have the biggest effect on value.
#
# Th fact that observations are clustered around the one popularity level for both Virgil and Travis, but spread across price, suggest the pricing of their sneakers is not sensitive or elastic to changes in popularity, there must be other underlying factors, however more data and research is required.

# %% [markdown]
# Since linear regressions don't seem to be a good fit, we are going to see more closely the evolution of these two time series for each pair.

# %% [markdown]
# - Jordan

# %% [markdown]
# ![MichaelAJ1_ev.JPG](attachment:MichaelAJ1_ev.JPG)

# %% [markdown]
# For Micahel Jordan the trend is clear, prices were more or less stable between 800-1000 until April, when his docu-series was released both in the US and Worldwide, and after it they kept on going up. The previous spike in popularity in January is due to Kobe Bryant's death and funeral, in which Michael gave a speech.
#
# The fact the average price went consistently up after the Last Dance indicates how it would be interesting to  furhter study the media exposition in relation to the price.

# %% [markdown]
# ![LastDance.JPG](attachment:LastDance.JPG)

# %% [markdown]
# - Kanye

# %% [markdown]
# ![KanyeAY2_ev.JPG](attachment:KanyeAY2_ev.JPG)

# %% [markdown]
# For Kanye the relationship is a tad less obvious and visually represented it seems more probable that there is a lag between popularity and prices, suggesting that the controversies might come before the price change. The peaks in popularity are worth mentioning, the first one in April 2018 marked his return to Twitter and the live tweeting of his 'self-help book for creatives'.
# The second peak illustrates his meeting with Trump in the White House. However none of these events significantly affects the price.
# The next peak is on october 2019 when he declared himself the greates artist of all time.
#
# The price tremendously soars on March of this year when Kanye stole the show with his Yeezy colection at the Paris Fashion Week, further confirming his status in the fashion industry.

# %% [markdown]
# - Travis Scott

# %% [markdown]
# ![TravisAJ1_ev.JPG](attachment:TravisAJ1_ev.JPG)

# %% [markdown]
# The prices remained at about 1200 until late February, when a new model endorsed by him came out thus lowering the value of this particular model, as we see for his peak in popularity. They began rising again, along with his popularity, when he gave an online concert in Fortnite, in which his charachter wore this model, so the prices began soaring up again and stayed there even if the searches went down.

# %% [markdown]
# - Virgil Abloh

# %% [markdown]
# ![VirgilOW_ev.JPG](attachment:VirgilOW_ev.JPG)

# %% [markdown]
# The first peak in popularity was on March 2018 when he became the creative director of Louis Vuitton and we see the price going up a bit, then peaking again in June, when he presented his first collection for the brand. The trend started going up again in December and up until August with more or less consiistently stationary beahviour. We see an increase in price volatility from September 2019 on the Paris Fashion Week similar to Kanye's. His peak in searches in June, had some backlash on prices, given the nature of his comments on the protests against police brutality in which he first lamented the looting of stores instead of the loss of black lives.

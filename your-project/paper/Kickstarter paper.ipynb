# %% [markdown]
# ![kickstarter-logo-wide.jpg](attachment:kickstarter-logo-wide.jpg)

# %% [markdown]
# Who hasn't thought about rasing some money in order to start a new project or a side-project? Well, raising money might not be as hard as everyone thinks, nowadays. [Kickstarter](https://www.kickstarter.com/) is a funding platform, its all-or-nothing model allows you to choose a funding goal and a set number of days to reach that goal. This way, you don’t get stuck without enough funds to realize your project. It also gives backers incentive to pledge more to help you reach your goal.

# %% [markdown]
# ![Captura.JPG](attachment:Captura.JPG)

# %% [markdown]
# The first time I heard about Kickstarter I really loved it, because it is very practical and useful. Therefore, I decided to start my project about how to succeed in this platform and what makes a project get over funded in this platform. Since projects do not limit their funding to a maxixum, which means that a project can actually get as much funding as investors are willing to invest.

# %% [markdown]
# In order to start my analysis, I had to begin by looking at which were the categories which had higher and lower success rate (investment >= goal). What led me to find out that most kickstarters fail, since the total success rate is 42%.

# %% [markdown]
# ![success_rate.JPG](attachment:success_rate.JPG)

# %% [markdown]
# What surprised me the most, was that Technology was the category with the lowest success rate of all. I most certainly not expected that. I wanted to know a little bit more about how was the average investment per project per category (including successful projects and failed ones.

# %% [markdown]
# ![Total2.JPG](attachment:Total2.JPG)

# %% [markdown]
# My first conclusion became clear when seeing this chart, technological projects must have a pretty high goal since the are the second category which have higher investment per project but only have a success rate of 23%. Most likely, technological projects are putting higher goals because of all the technological hype there always is.
#
# Therefore, I checked the top 3 highest average goal per category and confirmed my hypothesis.
#
#
# ![avg%20goal.JPG](attachment:avg%20goal.JPG)

# %% [markdown]
# I came up with an idea, let's make an investment vs goal ratio. Meaning each successful project will have an ig ratio equal or higher to one. This way, I could calculate the average ratio per category in order to see, which categories have it higher. The top 5 categories with higher ig ratio are:
#
#
# ![percentage%20funded.JPG](attachment:percentage%20funded.JPG)

# %% [markdown]
# At first, I was pretty surprised by this result. How could technology have a success rate of 23% and be the 4th category with higher ig ratio? However, it was pretty clear that there were some projects with a pretty low goal or an unexpectedly high funding and that were making this ratio higher for the whole category. Therefore, I decided to check all the anomalies in the categories with highest and lowest success rates.
#
# ![variance.JPG](attachment:variance.JPG)

# %% [markdown]
# It was perfectly clear that there were too many anomalies in certain categories and these anomalies made the average ratio value much higher. Since having projects with a ratio over 800 and many others between 50 and 300 when most part of the projects ratio is between 0 and 3 makes the value much higher. Specially due to the fact that the ratio will be always limit to 0 on the lower part but won't have any type of limit on the higher part.

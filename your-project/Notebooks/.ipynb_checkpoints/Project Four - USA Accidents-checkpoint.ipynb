# %% [markdown]
# Dataset = https://www.kaggle.com/sobhanmoosavi/us-accidents

# %% [markdown]
# ## Part Zero - Initial Imports and Options

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
from scipy.stats import norm
from scipy.stats import t
from scipy import stats

# %%
accidents_original = pd.read_csv(r"C:\Users\Gareth\Desktop\Ironhack\Week_Five\Project-Week-5-Your-Own-Project\Database\US_Accidents_Dec19.csv")

# %%
data = pd.read_csv(r"C:\Users\Gareth\Desktop\Ironhack\Week_Five\Project-Week-5-Your-Own-Project\Database\US_Accidents_Dec19.csv")

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Part One - Data Cleaning

# %% [markdown]
# ### Data wrangling - converting objects to the correct type, dropping columns where unnessecary.

# %%
data.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  \
# 0  39.865147 -84.058723      NaN      NaN          0.01
# 1  39.928059 -82.831184      NaN      NaN          0.01
# 2  39.063148 -84.032608      NaN      NaN          0.01
# 3  39.747753 -84.205582      NaN      NaN          0.01
# 4  39.627781 -84.188354      NaN      NaN          0.01
#
#                                          Description  Number  \
# 0  Right lane blocked due to accident on I-70 Eas...     NaN
# 1  Accident on Brice Rd at Tussing Rd. Expect del...  2584.0
# 2  Accident on OH-32 State Route 32 Westbound at ...     NaN
# 3  Accident on I-75 Southbound at Exits 52 52B US...     NaN
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...     NaN
#
#                       Street Side          City      County State     Zipcode  \
# 0                     I-70 E    R        Dayton  Montgomery    OH       45424
# 1                   Brice Rd    L  Reynoldsburg    Franklin    OH  43068-3402
# 2             State Route 32    R  Williamsburg    Clermont    OH       45176
# 3                     I-75 S    R        Dayton  Montgomery    OH       45417
# 4  Miamisburg Centerville Rd    R        Dayton  Montgomery    OH       45459
#
#   Country    Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0      US  US/Eastern         KFFO  2016-02-08 05:58:00            36.9
# 1      US  US/Eastern         KCMH  2016-02-08 05:51:00            37.9
# 2      US  US/Eastern         KI69  2016-02-08 06:56:00            36.0
# 3      US  US/Eastern         KDAY  2016-02-08 07:38:00            35.1
# 4      US  US/Eastern         KMGY  2016-02-08 07:53:00            36.0
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 0            NaN         91.0         29.68            10.0           Calm
# 1            NaN        100.0         29.65            10.0           Calm
# 2           33.3        100.0         29.67            10.0             SW
# 3           31.0         96.0         29.64             9.0             SW
# 4           33.3         89.0         29.65             6.0             SW
#
#    Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 0              NaN               0.02        Light Rain    False  False
# 1              NaN               0.00        Light Rain    False  False
# 2              3.5                NaN          Overcast    False  False
# 3              4.6                NaN     Mostly Cloudy    False  False
# 4              3.5                NaN     Mostly Cloudy    False  False
#
#    Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0     False     False     False    False    False       False    False  False
# 1     False     False     False    False    False       False    False  False
# 2     False     False     False    False    False       False    False  False
# 3     False     False     False    False    False       False    False  False
# 4     False     False     False    False    False       False    False  False
#
#    Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0            False           False         False          Night
# 1            False           False         False          Night
# 2            False            True         False          Night
# 3            False           False         False          Night
# 4            False            True         False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day

# %%
data['Start_Time'].dtypes
# Out:
# dtype('O')

# %%
data['Start_Time'] = pd.to_datetime(data['Start_Time'])
data['End_Time'] = pd.to_datetime(data['End_Time'])

# %%
data['Start_Time'] = data['Start_Time'].dt.normalize()
data['End_Time'] = data['End_Time'].dt.normalize()

# %%
data['Start_Time'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
data['End_Time'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
data.head()
# Out:
#     ID    Source    TMC  Severity Start_Time   End_Time  Start_Lat  Start_Lng  \
# 0  A-1  MapQuest  201.0         3 2016-02-08 2016-02-08  39.865147 -84.058723
# 1  A-2  MapQuest  201.0         2 2016-02-08 2016-02-08  39.928059 -82.831184
# 2  A-3  MapQuest  201.0         2 2016-02-08 2016-02-08  39.063148 -84.032608
# 3  A-4  MapQuest  201.0         3 2016-02-08 2016-02-08  39.747753 -84.205582
# 4  A-5  MapQuest  201.0         2 2016-02-08 2016-02-08  39.627781 -84.188354
#
#    End_Lat  End_Lng  Distance(mi)  \
# 0      NaN      NaN          0.01
# 1      NaN      NaN          0.01
# 2      NaN      NaN          0.01
# 3      NaN      NaN          0.01
# 4      NaN      NaN          0.01
#
#                                          Description  Number  \
# 0  Right lane blocked due to accident on I-70 Eas...     NaN
# 1  Accident on Brice Rd at Tussing Rd. Expect del...  2584.0
# 2  Accident on OH-32 State Route 32 Westbound at ...     NaN
# 3  Accident on I-75 Southbound at Exits 52 52B US...     NaN
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...     NaN
#
#                       Street Side          City      County State     Zipcode  \
# 0                     I-70 E    R        Dayton  Montgomery    OH       45424
# 1                   Brice Rd    L  Reynoldsburg    Franklin    OH  43068-3402
# 2             State Route 32    R  Williamsburg    Clermont    OH       45176
# 3                     I-75 S    R        Dayton  Montgomery    OH       45417
# 4  Miamisburg Centerville Rd    R        Dayton  Montgomery    OH       45459
#
#   Country    Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0      US  US/Eastern         KFFO  2016-02-08 05:58:00            36.9
# 1      US  US/Eastern         KCMH  2016-02-08 05:51:00            37.9
# 2      US  US/Eastern         KI69  2016-02-08 06:56:00            36.0
# 3      US  US/Eastern         KDAY  2016-02-08 07:38:00            35.1
# 4      US  US/Eastern         KMGY  2016-02-08 07:53:00            36.0
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 0            NaN         91.0         29.68            10.0           Calm
# 1            NaN        100.0         29.65            10.0           Calm
# 2           33.3        100.0         29.67            10.0             SW
# 3           31.0         96.0         29.64             9.0             SW
# 4           33.3         89.0         29.65             6.0             SW
#
#    Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 0              NaN               0.02        Light Rain    False  False
# 1              NaN               0.00        Light Rain    False  False
# 2              3.5                NaN          Overcast    False  False
# 3              4.6                NaN     Mostly Cloudy    False  False
# 4              3.5                NaN     Mostly Cloudy    False  False
#
#    Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0     False     False     False    False    False       False    False  False
# 1     False     False     False    False    False       False    False  False
# 2     False     False     False    False    False       False    False  False
# 3     False     False     False    False    False       False    False  False
# 4     False     False     False    False    False       False    False  False
#
#    Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0            False           False         False          Night
# 1            False           False         False          Night
# 2            False            True         False          Night
# 3            False           False         False          Night
# 4            False            True         False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day

# %% [markdown]
# ### Select timeframe of one year.

# %%
data_year = data[(data['Start_Time'] > '2016-08-23') &
                (data['Start_Time'] <= '2019-08-23')]

# %% [markdown]
# ### Which columns have null values?

# %%
data_year.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                       530404
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  1887814
# End_Lng                  1887814
# Distance(mi)                   0
# Description                    1
# Number                   1549540
# Street                         0
# Side                           0
# City                          61
# County                         0
# State                          0
# Zipcode                      716
# Country                        0
# Timezone                    2544
# Airport_Code                4725
# Weather_Timestamp          30560
# Temperature(F)             46151
# Wind_Chill(F)            1686162
# Humidity(%)                48566
# Pressure(in)               40530
# Visibility(mi)             55057
# Wind_Direction             34610
# Wind_Speed(mph)           405389
# Precipitation(in)        1827108
# Weather_Condition          55459
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                63
# Civil_Twilight                63
# Nautical_Twilight             63
# Astronomical_Twilight         63
# dtype: int64

# %% [markdown]
# ### Drop columns that aren't needed for our study.

# %%
data_year = data_year.drop(columns = ['Number','End_Time','Wind_Chill(F)','Street','Timezone','Airport_Code','End_Lat','End_Lng','Pressure(in)','Humidity(%)'])

# %% [markdown]
# ### Sort by Severity of Accident (4 = Most Severe, 1 = Least Severe)

# %%
data_year = data_year.sort_values(by = 'Severity', ascending = False)

# %%
data_year['Start_Time'].min()
# Out:
# Timestamp('2016-08-24 00:00:00')

# %% [markdown]
# ### Export to CSV to reduce dataset size for easier loading with Tableau.

# %%
data_year.to_csv(r"C:\Users\Gareth\Desktop\Ironhack\Week_Five\Project-Week-5-Your-Own-Project\Database\DataYearAccidents.csv")

# %% [markdown]
# ### Severity over Time

# %%
severity_time = data_year[['Severity','Start_Time']]
severity_time['Start_Time'] = severity_time['Start_Time'].dt.date

severity_time.head()
# Out:
# C:\Users\Gareth\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Severity  Start_Time
# 2814574         4  2018-02-09
# 2269426         4  2016-10-03
# 2688102         4  2018-12-25
# 2688103         4  2018-12-25
# 2688104         4  2018-12-25

# %%
sev_count = severity_time.groupby(severity_time['Start_Time'])['Severity'].value_counts()
sev_count.head()
# Out:
# Start_Time  Severity
# 2016-08-24  2           1606
#             3            634
#             4             74
#             1              3
# 2016-08-25  2           1364
# Name: Severity, dtype: int64

# %%
sev_count = severity_time.groupby(severity_time['Start_Time'])['Severity'].value_counts().unstack(level = 1)
sev_count.reset_index(level=0, inplace=True)
sev_count
# Out:
# Severity  Start_Time    1       2      3     4
# 0         2016-08-24  3.0  1606.0  634.0  74.0
# 1         2016-08-25  NaN  1364.0  652.0  62.0
# 2         2016-08-26  3.0  1572.0  680.0  73.0
# 3         2016-08-27  2.0   355.0  308.0  38.0
# 4         2016-08-28  2.0   326.0  298.0  61.0
# ...              ...  ...     ...    ...   ...
# 1090      2019-08-19  2.0  1923.0  638.0  82.0
# 1091      2019-08-20  NaN  2200.0  663.0  88.0
# 1092      2019-08-21  NaN  2103.0  676.0  71.0
# 1093      2019-08-22  NaN  2168.0  734.0  81.0
# 1094      2019-08-23  1.0  2087.0  680.0  58.0
#
# [1095 rows x 5 columns]

# %%
from scipy.interpolate import interp1d

# %%
x = sev_count.Start_Time
y = sev_count[2]
f = interp1d(x, y)

# %%
plt.figure(figsize=(16, 10))
plt.plot(sev_count.Start_Time, sev_count[1], label = 'Severity 1', markevery = 5)
plt.plot(sev_count.Start_Time, sev_count[2], label = 'Severity 2', markevery = 5)
plt.plot(sev_count.Start_Time, sev_count[3], label = 'Severity 3', markevery = 5)
plt.plot(sev_count.Start_Time, sev_count[4], label = 'Severity 4', markevery = 5)

plt.xlabel('Date')
plt.ylabel('# of Accidents')
plt.title('# of Accidents by Severity against Time')
plt.legend()
plt.show()

# %% [markdown]
# ### Count Accidents By State

# %%
accidents_by_state = [data_year[data_year['State'] == i].count()['ID'] 
                      for i in data_year.State.unique()]

accidents_by_state.sort(reverse = True)

# %%
states = data_year.State.unique()

# %%
state_severity = data_year[['Severity', 'ID', 'State']]
state_severity
# Out:
#          Severity         ID State
# 2814574         4  A-2814598    NY
# 2269426         4  A-2269450    TX
# 2688102         4  A-2688126    AZ
# 2688103         4  A-2688127    AZ
# 2688104         4  A-2688128    AZ
# ...           ...        ...   ...
# 146407          1   A-146409    GA
# 1393931         1  A-1393947    TX
# 332233          1   A-332236    TX
# 376988          1   A-376992    OH
# 2187425         1  A-2187449    PA
#
# [2418218 rows x 3 columns]

# %%
grouped = state_severity.groupby(['State']).sum().reset_index()
grouped.head()
# Out:
#   State  Severity
# 0    AL     70186
# 1    AR      4054
# 2    AZ    120689
# 3    CA   1107610
# 4    CO     85333

# %%
sort_grouped = grouped.sort_values(by = 'Severity', ascending = False)
sort_grouped.head()
# Out:
#    State  Severity
# 3     CA   1107610
# 41    TX    583689
# 8     FL    456193
# 32    NY    284274
# 38    SC    272430

# %%
sns.set(style="white", context="talk")

fig, ax = plt.subplots(figsize=(16,10)) 
sns.barplot(x = sort_grouped['Severity'], y = sort_grouped['State'])
plt.xticks(rotation=90)
plt.yticks(fontsize = 12)
plt.title('# of Accidents by State Aug 2016 - Aug 2019', fontsize = 30)
plt.xlabel('# of Accidents', fontsize = 20)
plt.ylabel('State', fontsize = 20)
# Out:
# Text(0, 0.5, 'State')

# %% [markdown]
# ### DO THIS PART

# %% [markdown]
# ### Severity by State

# %%
sev1_by_state = []
sev2_by_state = []
sev3_by_state = []
sev4_by_state = []

for i in sort_grouped['State']:
    sev1_by_state.append(sort_grouped[(sort_grouped['Severity'] == 1).count()
                         &(sort_grouped['State'] == i)])
    sev2_by_state.append(sort_grouped[(sort_grouped['Severity'] == 2).count()
                         &(sort_grouped['State'] == i)])
    sev3_by_state.append(sort_grouped[(sort_grouped['Severity'] == 3).count()
                         &(sort_grouped['State'] == i)])
    sev4_by_state.append(sort_grouped[(sort_grouped['Severity'] == 4).count()
                         &(sort_grouped['State'] == i)])

# %%
type(sev1_by_state)
# Out:
# list

# %% [markdown]
# ### Most Common Weather Conditions during an Accident

# %%
sns.set(style="white", context="talk")

fig, ax = plt.subplots(figsize=(16,10)) 
data_year['Weather_Condition'].value_counts().head(10).plot.bar(color = ['coral', 
                                                                         'darkorange',
                                                                         'limegreen', 
                                                                         'navy', 
                                                                         'orchid',
                                                                         'slateblue',
                                                                        'teal',
                                                                        'royalblue',
                                                                        'lightsteelblue',
                                                                        'darkblue'],
                                                               alpha = 0.75)
plt.xlabel('Weather Condition', fontsize = 20)
plt.ylabel('# of Accidents', fontsize = 20)
ax.tick_params(labelsize= 15)
plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.title('Most Common Weather Conditions at the time of Accident', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Most Common Weather Conditions at the time of Accident')

# %% [markdown]
# ### Create columns to split Weather Conditions which contain ' / '

# %%
data_year['Weather_Condition 1'] = data_year['Weather_Condition'].str.split('/').str[0].str.strip()
data_year['Weather_Condition 2'] = data_year['Weather_Condition'].str.split('/').str[1].str.strip()
data_year['Weather_Condition 3'] = data_year['Weather_Condition'].str.split('/').str[2].str.strip()
#data_year['Weather_Condition 4'] = data_year['Weather_Condition'].str.split('and').str[3]
#data_year['Weather_Condition 5'] = data_year['Weather_Condition'].str.split('and').str[4]

data_year.head()
# Out:
#                 ID Source  TMC  Severity Start_Time  Start_Lat   Start_Lng  \
# 2814574  A-2814598   Bing  NaN         4 2018-02-09  42.353330  -74.070120
# 2269426  A-2269450   Bing  NaN         4 2016-10-03  30.074080  -95.503131
# 2688102  A-2688126   Bing  NaN         4 2018-12-25  33.556060 -112.112250
# 2688103  A-2688127   Bing  NaN         4 2018-12-25  33.386550 -111.759640
# 2688104  A-2688128   Bing  NaN         4 2018-12-25  34.552714 -112.426958
#
#          Distance(mi)                                        Description Side  \
# 2814574         1.579  Closed at CR-31/Roosevelt Ave - Road closed du...    L
# 2269426         0.474  Closed between FM-2920 and I-45/North Fwy - Ro...    R
# 2688102         0.164  Ramp closed to Northern Ave/Exit 206 - Road cl...    R
# 2688103         1.968  Closed between Val Vista Dr/Exit 184 and Gilbe...    R
# 2688104         0.297  Closed at Yavpe Conn - Road closed due to acci...    L
#
#              City    County State     Zipcode Country    Weather_Timestamp  \
# 2814574     Cairo    Greene    NY  12413-2009      US  2018-02-09 08:51:00
# 2269426    Spring    Harris    TX  77388-3005      US  2016-10-03 16:53:00
# 2688102   Phoenix  Maricopa    AZ  85021-4857      US  2018-12-25 00:53:00
# 2688103      Mesa  Maricopa    AZ       85204      US  2018-12-25 02:54:00
# 2688104  Prescott   Yavapai    AZ       86301      US  2018-12-25 19:53:00
#
#          Temperature(F)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 2814574             9.0            10.0           Calm              NaN
# 2269426            84.9            10.0       Variable              3.5
# 2688102            52.0            10.0            NNE              3.5
# 2688103            50.0            10.0             NE              4.6
# 2688104            35.1             9.0             SW              9.2
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# 2814574                NaN     Mostly Cloudy    False  False     False
# 2269426                NaN             Clear    False  False     False
# 2688102                NaN             Clear    False  False     False
# 2688103                NaN             Clear    False  False     False
# 2688104                NaN             Clear    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 2814574     False     False    False    False       False    False  False
# 2269426     False     False    False    False       False    False  False
# 2688102     False     False    False    False       False    False  False
# 2688103     False     False    False    False       False    False  False
# 2688104     False     False    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 2814574            False           False         False            Day
# 2269426            False            True         False            Day
# 2688102            False           False         False          Night
# 2688103            False           False         False          Night
# 2688104            False           False         False          Night
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 2814574            Day               Day                   Day
# 2269426            Day               Day                   Day
# 2688102          Night             Night                 Night
# 2688103          Night             Night                 Night
# 2688104          Night             Night                 Night
#
#         Weather_Condition 1 Weather_Condition 2 Weather_Condition 3
# 2814574       Mostly Cloudy                 NaN                 NaN
# 2269426               Clear                 NaN                 NaN
# 2688102               Clear                 NaN                 NaN
# 2688103               Clear                 NaN                 NaN
# 2688104               Clear                 NaN                 NaN

# %% [markdown]
# #### Check to see if it's worked...

# %%
data_year.loc[data_year['Weather_Condition'] == 'Sand / Dust Whirlwinds / Windy']
# Out:
#               ID    Source    TMC  Severity Start_Time  Start_Lat   Start_Lng  \
# 796576  A-796585  MapQuest  201.0         2 2019-07-11  33.379162 -111.753967
# 796573  A-796582  MapQuest  201.0         2 2019-07-11  33.553162 -112.151573
#
#         Distance(mi)                               Description Side      City  \
# 796576           0.0  Accident on Baseline Rd at Val Vista Dr.    R   Gilbert
# 796573           0.0     Accident on 43rd Ave at Northern Ave.    L  Glendale
#
#           County State     Zipcode Country    Weather_Timestamp  \
# 796576  Maricopa    AZ       85234      US  2019-07-11 17:50:00
# 796573  Maricopa    AZ  85302-6601      US  2019-07-11 16:58:00
#
#         Temperature(F)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 796576           109.0            10.0            WNW             24.0
# 796573           111.0            10.0            WSW             22.0
#
#         Precipitation(in)               Weather_Condition  Amenity   Bump  \
# 796576                0.0  Sand / Dust Whirlwinds / Windy    False  False
# 796573                0.0  Sand / Dust Whirlwinds / Windy    False  False
#
#         Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station  \
# 796576      True     False     False    False    False       False    False
# 796573      True     False     False    False    False       False    False
#
#          Stop  Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 796576  False            False            True         False            Day
# 796573  False            False            True         False            Day
#
#        Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 796576            Day               Day                   Day
# 796573            Day               Day                   Day
#
#        Weather_Condition 1 Weather_Condition 2 Weather_Condition 3
# 796576                Sand     Dust Whirlwinds               Windy
# 796573                Sand     Dust Whirlwinds               Windy

# %% [markdown]
# ### Splitting Weather Conditions + Severity into New DF

# %%
df_unmerged = data_year[['Severity',
                         'Weather_Condition 1',
                         'Weather_Condition 2',
                         'Weather_Condition 3']]

df_unmerged
# Out:
#          Severity           Weather_Condition 1 Weather_Condition 2  \
# 2814574         4                 Mostly Cloudy                 NaN
# 2269426         4                         Clear                 NaN
# 2688102         4                         Clear                 NaN
# 2688103         4                         Clear                 NaN
# 2688104         4                         Clear                 NaN
# ...           ...                           ...                 ...
# 146407          1                         Clear                 NaN
# 1393931         1  Light Thunderstorms and Rain                 NaN
# 332233          1                         Clear                 NaN
# 376988          1                 Mostly Cloudy                 NaN
# 2187425         1                         Clear                 NaN
#
#         Weather_Condition 3
# 2814574                 NaN
# 2269426                 NaN
# 2688102                 NaN
# 2688103                 NaN
# 2688104                 NaN
# ...                     ...
# 146407                  NaN
# 1393931                 NaN
# 332233                  NaN
# 376988                  NaN
# 2187425                 NaN
#
# [2418218 rows x 4 columns]

# %%
df_unmerged = df_unmerged.loc[df_unmerged['Weather_Condition 1'].notna()]

# %%
df_unmerged.shape
# Out:
# (2362759, 4)

# %%
df_unmerged.isna().sum()
# Out:
# Severity                     0
# Weather_Condition 1          0
# Weather_Condition 2    2356874
# Weather_Condition 3    2362756
# dtype: int64

# %%
df_unmerged.drop(columns = ['Weather_Condition 2', 'Weather_Condition 3'], inplace = True)
# Out:
# C:\Users\Gareth\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### Export to CSV as previous methods are resource intensive.

# %%
df_unmerged.to_csv(r"C:\Users\Gareth\Desktop\Ironhack\Week_Five\Project-Week-5-Your-Own-Project\Database\Dummies_Data.csv")

# %% [markdown]
# ### Creating Dummies for Correlation

# %%
dummies = pd.get_dummies(df_unmerged)
dummies.head()
# Out:
#          Severity  Weather_Condition 1_Blowing Dust  \
# 2814574         4                                 0
# 2269426         4                                 0
# 2688102         4                                 0
# 2688103         4                                 0
# 2688104         4                                 0
#
#          Weather_Condition 1_Blowing Snow  Weather_Condition 1_Clear  \
# 2814574                                 0                          0
# 2269426                                 0                          1
# 2688102                                 0                          1
# 2688103                                 0                          1
# 2688104                                 0                          1
#
#          Weather_Condition 1_Cloudy  Weather_Condition 1_Drizzle  \
# 2814574                           0                            0
# 2269426                           0                            0
# 2688102                           0                            0
# 2688103                           0                            0
# 2688104                           0                            0
#
#          Weather_Condition 1_Drizzle and Fog  Weather_Condition 1_Dust Whirls  \
# 2814574                                    0                                0
# 2269426                                    0                                0
# 2688102                                    0                                0
# 2688103                                    0                                0
# 2688104                                    0                                0
#
#          Weather_Condition 1_Fair  Weather_Condition 1_Fog  \
# 2814574                         0                        0
# 2269426                         0                        0
# 2688102                         0                        0
# 2688103                         0                        0
# 2688104                         0                        0
#
#          Weather_Condition 1_Freezing Rain  Weather_Condition 1_Funnel Cloud  \
# 2814574                                  0                                 0
# 2269426                                  0                                 0
# 2688102                                  0                                 0
# 2688103                                  0                                 0
# 2688104                                  0                                 0
#
#          Weather_Condition 1_Hail  Weather_Condition 1_Haze  \
# 2814574                         0                         0
# 2269426                         0                         0
# 2688102                         0                         0
# 2688103                         0                         0
# 2688104                         0                         0
#
#          Weather_Condition 1_Heavy Blowing Snow  \
# 2814574                                       0
# 2269426                                       0
# 2688102                                       0
# 2688103                                       0
# 2688104                                       0
#
#          Weather_Condition 1_Heavy Drizzle  \
# 2814574                                  0
# 2269426                                  0
# 2688102                                  0
# 2688103                                  0
# 2688104                                  0
#
#          Weather_Condition 1_Heavy Freezing Drizzle  \
# 2814574                                           0
# 2269426                                           0
# 2688102                                           0
# 2688103                                           0
# 2688104                                           0
#
#          Weather_Condition 1_Heavy Freezing Rain  \
# 2814574                                        0
# 2269426                                        0
# 2688102                                        0
# 2688103                                        0
# 2688104                                        0
#
#          Weather_Condition 1_Heavy Ice Pellets  \
# 2814574                                      0
# 2269426                                      0
# 2688102                                      0
# 2688103                                      0
# 2688104                                      0
#
#          Weather_Condition 1_Heavy Rain  \
# 2814574                               0
# 2269426                               0
# 2688102                               0
# 2688103                               0
# 2688104                               0
#
#          Weather_Condition 1_Heavy Rain Showers  \
# 2814574                                       0
# 2269426                                       0
# 2688102                                       0
# 2688103                                       0
# 2688104                                       0
#
#          Weather_Condition 1_Heavy Smoke  Weather_Condition 1_Heavy Snow  \
# 2814574                                0                               0
# 2269426                                0                               0
# 2688102                                0                               0
# 2688103                                0                               0
# 2688104                                0                               0
#
#          Weather_Condition 1_Heavy Snow with Thunder  \
# 2814574                                            0
# 2269426                                            0
# 2688102                                            0
# 2688103                                            0
# 2688104                                            0
#
#          Weather_Condition 1_Heavy T-Storm  \
# 2814574                                  0
# 2269426                                  0
# 2688102                                  0
# 2688103                                  0
# 2688104                                  0
#
#          Weather_Condition 1_Heavy Thunderstorms and Rain  \
# 2814574                                                 0
# 2269426                                                 0
# 2688102                                                 0
# 2688103                                                 0
# 2688104                                                 0
#
#          Weather_Condition 1_Heavy Thunderstorms and Snow  \
# 2814574                                                 0
# 2269426                                                 0
# 2688102                                                 0
# 2688103                                                 0
# 2688104                                                 0
#
#          Weather_Condition 1_Heavy Thunderstorms with Small Hail  \
# 2814574                                                  0
# 2269426                                                  0
# 2688102                                                  0
# 2688103                                                  0
# 2688104                                                  0
#
#          Weather_Condition 1_Ice Pellets  \
# 2814574                                0
# 2269426                                0
# 2688102                                0
# 2688103                                0
# 2688104                                0
#
#          Weather_Condition 1_Light Blowing Snow  \
# 2814574                                       0
# 2269426                                       0
# 2688102                                       0
# 2688103                                       0
# 2688104                                       0
#
#          Weather_Condition 1_Light Drizzle  Weather_Condition 1_Light Fog  \
# 2814574                                  0                              0
# 2269426                                  0                              0
# 2688102                                  0                              0
# 2688103                                  0                              0
# 2688104                                  0                              0
#
#          Weather_Condition 1_Light Freezing Drizzle  \
# 2814574                                           0
# 2269426                                           0
# 2688102                                           0
# 2688103                                           0
# 2688104                                           0
#
#          Weather_Condition 1_Light Freezing Fog  \
# 2814574                                       0
# 2269426                                       0
# 2688102                                       0
# 2688103                                       0
# 2688104                                       0
#
#          Weather_Condition 1_Light Freezing Rain  \
# 2814574                                        0
# 2269426                                        0
# 2688102                                        0
# 2688103                                        0
# 2688104                                        0
#
#          Weather_Condition 1_Light Hail  Weather_Condition 1_Light Haze  \
# 2814574                               0                               0
# 2269426                               0                               0
# 2688102                               0                               0
# 2688103                               0                               0
# 2688104                               0                               0
#
#          Weather_Condition 1_Light Ice Pellets  \
# 2814574                                      0
# 2269426                                      0
# 2688102                                      0
# 2688103                                      0
# 2688104                                      0
#
#          Weather_Condition 1_Light Rain  \
# 2814574                               0
# 2269426                               0
# 2688102                               0
# 2688103                               0
# 2688104                               0
#
#          Weather_Condition 1_Light Rain Shower  \
# 2814574                                      0
# 2269426                                      0
# 2688102                                      0
# 2688103                                      0
# 2688104                                      0
#
#          Weather_Condition 1_Light Rain Showers  \
# 2814574                                       0
# 2269426                                       0
# 2688102                                       0
# 2688103                                       0
# 2688104                                       0
#
#          Weather_Condition 1_Light Rain with Thunder  \
# 2814574                                            0
# 2269426                                            0
# 2688102                                            0
# 2688103                                            0
# 2688104                                            0
#
#          Weather_Condition 1_Light Snow  \
# 2814574                               0
# 2269426                               0
# 2688102                               0
# 2688103                               0
# 2688104                               0
#
#          Weather_Condition 1_Light Snow Grains  \
# 2814574                                      0
# 2269426                                      0
# 2688102                                      0
# 2688103                                      0
# 2688104                                      0
#
#          Weather_Condition 1_Light Snow Showers  \
# 2814574                                       0
# 2269426                                       0
# 2688102                                       0
# 2688103                                       0
# 2688104                                       0
#
#          Weather_Condition 1_Light Snow and Sleet  \
# 2814574                                         0
# 2269426                                         0
# 2688102                                         0
# 2688103                                         0
# 2688104                                         0
#
#          Weather_Condition 1_Light Snow with Thunder  \
# 2814574                                            0
# 2269426                                            0
# 2688102                                            0
# 2688103                                            0
# 2688104                                            0
#
#          Weather_Condition 1_Light Thunderstorm  \
# 2814574                                       0
# 2269426                                       0
# 2688102                                       0
# 2688103                                       0
# 2688104                                       0
#
#          Weather_Condition 1_Light Thunderstorms and Rain  \
# 2814574                                                 0
# 2269426                                                 0
# 2688102                                                 0
# 2688103                                                 0
# 2688104                                                 0
#
#          Weather_Condition 1_Light Thunderstorms and Snow  \
# 2814574                                                 0
# 2269426                                                 0
# 2688102                                                 0
# 2688103                                                 0
# 2688104                                                 0
#
#          Weather_Condition 1_Low Drifting Snow  Weather_Condition 1_Mist  \
# 2814574                                      0                         0
# 2269426                                      0                         0
# 2688102                                      0                         0
# 2688103                                      0                         0
# 2688104                                      0                         0
#
#          Weather_Condition 1_Mostly Cloudy  Weather_Condition 1_N  \
# 2814574                                  1                      0
# 2269426                                  0                      0
# 2688102                                  0                      0
# 2688103                                  0                      0
# 2688104                                  0                      0
#
#          Weather_Condition 1_Overcast  Weather_Condition 1_Partly Cloudy  \
# 2814574                             0                                  0
# 2269426                             0                                  0
# 2688102                             0                                  0
# 2688103                             0                                  0
# 2688104                             0                                  0
#
#          Weather_Condition 1_Patches of Fog  Weather_Condition 1_Rain  \
# 2814574                                   0                         0
# 2269426                                   0                         0
# 2688102                                   0                         0
# 2688103                                   0                         0
# 2688104                                   0                         0
#
#          Weather_Condition 1_Rain Shower  Weather_Condition 1_Rain Showers  \
# 2814574                                0                                 0
# 2269426                                0                                 0
# 2688102                                0                                 0
# 2688103                                0                                 0
# 2688104                                0                                 0
#
#          Weather_Condition 1_Sand  Weather_Condition 1_Scattered Clouds  \
# 2814574                         0                                     0
# 2269426                         0                                     0
# 2688102                         0                                     0
# 2688103                         0                                     0
# 2688104                         0                                     0
#
#          Weather_Condition 1_Shallow Fog  \
# 2814574                                0
# 2269426                                0
# 2688102                                0
# 2688103                                0
# 2688104                                0
#
#          Weather_Condition 1_Showers in the Vicinity  \
# 2814574                                            0
# 2269426                                            0
# 2688102                                            0
# 2688103                                            0
# 2688104                                            0
#
#          Weather_Condition 1_Small Hail  Weather_Condition 1_Smoke  \
# 2814574                               0                          0
# 2269426                               0                          0
# 2688102                               0                          0
# 2688103                               0                          0
# 2688104                               0                          0
#
#          Weather_Condition 1_Snow  Weather_Condition 1_Snow Grains  \
# 2814574                         0                                0
# 2269426                         0                                0
# 2688102                         0                                0
# 2688103                         0                                0
# 2688104                         0                                0
#
#          Weather_Condition 1_Snow Showers  Weather_Condition 1_Snow and Sleet  \
# 2814574                                 0                                   0
# 2269426                                 0                                   0
# 2688102                                 0                                   0
# 2688103                                 0                                   0
# 2688104                                 0                                   0
#
#          Weather_Condition 1_Snow and Thunder  Weather_Condition 1_Squalls  \
# 2814574                                     0                            0
# 2269426                                     0                            0
# 2688102                                     0                            0
# 2688103                                     0                            0
# 2688104                                     0                            0
#
#          Weather_Condition 1_T-Storm  Weather_Condition 1_Thunder  \
# 2814574                            0                            0
# 2269426                            0                            0
# 2688102                            0                            0
# 2688103                            0                            0
# 2688104                            0                            0
#
#          Weather_Condition 1_Thunder and Hail  \
# 2814574                                     0
# 2269426                                     0
# 2688102                                     0
# 2688103                                     0
# 2688104                                     0
#
#          Weather_Condition 1_Thunder in the Vicinity  \
# 2814574                                            0
# 2269426                                            0
# 2688102                                            0
# 2688103                                            0
# 2688104                                            0
#
#          Weather_Condition 1_Thunderstorm  \
# 2814574                                 0
# 2269426                                 0
# 2688102                                 0
# 2688103                                 0
# 2688104                                 0
#
#          Weather_Condition 1_Thunderstorms and Rain  \
# 2814574                                           0
# 2269426                                           0
# 2688102                                           0
# 2688103                                           0
# 2688104                                           0
#
#          Weather_Condition 1_Thunderstorms and Snow  \
# 2814574                                           0
# 2269426                                           0
# 2688102                                           0
# 2688103                                           0
# 2688104                                           0
#
#          Weather_Condition 1_Tornado  Weather_Condition 1_Volcanic Ash  \
# 2814574                            0                                 0
# 2269426                            0                                 0
# 2688102                            0                                 0
# 2688103                            0                                 0
# 2688104                            0                                 0
#
#          Weather_Condition 1_Widespread Dust  Weather_Condition 1_Wintry Mix
# 2814574                                    0                               0
# 2269426                                    0                               0
# 2688102                                    0                               0
# 2688103                                    0                               0
# 2688104                                    0                               0

# %%
pd.DataFrame(dummies.sum().sort_values(ascending = False))
# Out:
#                                             0
# Severity                              5612529
# Weather_Condition 1_Clear              737102
# Weather_Condition 1_Overcast           365212
# Weather_Condition 1_Mostly Cloudy      348138
# Weather_Condition 1_Partly Cloudy      238348
# ...                                       ...
# Weather_Condition 1_Dust Whirls             1
# Weather_Condition 1_Freezing Rain           1
# Weather_Condition 1_Snow and Thunder        1
# Weather_Condition 1_Heavy Smoke             1
# Weather_Condition 1_Thunder and Hail        1
#
# [83 rows x 1 columns]

# %%
dummies['Severity'].corr(dummies['Weather_Condition 1_Clear'])
# Out:
# -0.010620256102224272

# %% [markdown]
# ### Finding High (> 0.01 or <0.01) Correlation

# %%
columns = list(dummies.columns)
columns.remove('Severity')

correlation_values = []
weather_types = []

for column in columns:
    corr = dummies['Severity'].corr(dummies[column])
    if corr >= 0.01 or corr <= -0.01:
        print(f'The correlation for {column} = {corr}')
        print('------------------------------------------------------')
        weather_types.append(column)
        correlation_values.append(corr)
# Out:
# The correlation for Weather_Condition 1_Clear = -0.010620256102224272
# ------------------------------------------------------
# The correlation for Weather_Condition 1_Fair = -0.019425413302361846
# ------------------------------------------------------
# The correlation for Weather_Condition 1_Light Freezing Rain = 0.01086585905570625
# ------------------------------------------------------
# The correlation for Weather_Condition 1_Light Rain = 0.01062488178079427
# ------------------------------------------------------
# The correlation for Weather_Condition 1_Light Snow = 0.025837266016054863
# ------------------------------------------------------
# The correlation for Weather_Condition 1_Rain = 0.010703213163315359
# ------------------------------------------------------
# The correlation for Weather_Condition 1_Snow = 0.010952443777723924
# ------------------------------------------------------

# %%
weather_types = [item.replace('Weather_Condition 1_','') for item in weather_types]

# %%
sns.set(style="white", context="talk")
fig, ax = plt.subplots(figsize=(16,10)) 
sns.barplot(x = weather_types, y = correlation_values)
plt.xticks(rotation=90)
plt.title('Correlation: Weather Conditions and Accident Severity\n', fontsize = 30)
plt.xlabel('\nWeather Condition', fontsize = 30)
plt.xticks(fontsize = 20)
plt.ylabel('Correlation', fontsize = 30)
# Out:
# Text(0, 0.5, 'Correlation')

# %% [markdown]
# ### Severity Visualization

# %%
data.head()
# Out:
#     ID    Source    TMC  Severity Start_Time   End_Time  Start_Lat  Start_Lng  \
# 0  A-1  MapQuest  201.0         3 2016-02-08 2016-02-08  39.865147 -84.058723
# 1  A-2  MapQuest  201.0         2 2016-02-08 2016-02-08  39.928059 -82.831184
# 2  A-3  MapQuest  201.0         2 2016-02-08 2016-02-08  39.063148 -84.032608
# 3  A-4  MapQuest  201.0         3 2016-02-08 2016-02-08  39.747753 -84.205582
# 4  A-5  MapQuest  201.0         2 2016-02-08 2016-02-08  39.627781 -84.188354
#
#    End_Lat  End_Lng  Distance(mi)  \
# 0      NaN      NaN          0.01
# 1      NaN      NaN          0.01
# 2      NaN      NaN          0.01
# 3      NaN      NaN          0.01
# 4      NaN      NaN          0.01
#
#                                          Description  Number  \
# 0  Right lane blocked due to accident on I-70 Eas...     NaN
# 1  Accident on Brice Rd at Tussing Rd. Expect del...  2584.0
# 2  Accident on OH-32 State Route 32 Westbound at ...     NaN
# 3  Accident on I-75 Southbound at Exits 52 52B US...     NaN
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...     NaN
#
#                       Street Side          City      County State     Zipcode  \
# 0                     I-70 E    R        Dayton  Montgomery    OH       45424
# 1                   Brice Rd    L  Reynoldsburg    Franklin    OH  43068-3402
# 2             State Route 32    R  Williamsburg    Clermont    OH       45176
# 3                     I-75 S    R        Dayton  Montgomery    OH       45417
# 4  Miamisburg Centerville Rd    R        Dayton  Montgomery    OH       45459
#
#   Country    Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0      US  US/Eastern         KFFO  2016-02-08 05:58:00            36.9
# 1      US  US/Eastern         KCMH  2016-02-08 05:51:00            37.9
# 2      US  US/Eastern         KI69  2016-02-08 06:56:00            36.0
# 3      US  US/Eastern         KDAY  2016-02-08 07:38:00            35.1
# 4      US  US/Eastern         KMGY  2016-02-08 07:53:00            36.0
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 0            NaN         91.0         29.68            10.0           Calm
# 1            NaN        100.0         29.65            10.0           Calm
# 2           33.3        100.0         29.67            10.0             SW
# 3           31.0         96.0         29.64             9.0             SW
# 4           33.3         89.0         29.65             6.0             SW
#
#    Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 0              NaN               0.02        Light Rain    False  False
# 1              NaN               0.00        Light Rain    False  False
# 2              3.5                NaN          Overcast    False  False
# 3              4.6                NaN     Mostly Cloudy    False  False
# 4              3.5                NaN     Mostly Cloudy    False  False
#
#    Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0     False     False     False    False    False       False    False  False
# 1     False     False     False    False    False       False    False  False
# 2     False     False     False    False    False       False    False  False
# 3     False     False     False    False    False       False    False  False
# 4     False     False     False    False    False       False    False  False
#
#    Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0            False           False         False          Night
# 1            False           False         False          Night
# 2            False            True         False          Night
# 3            False           False         False          Night
# 4            False            True         False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day

# %%
severities4 = data[data['Severity'] == 4]['Severity'].value_counts()
severities3 = data[data['Severity'] == 3]['Severity'].value_counts()
severities2 = data[data['Severity'] == 2]['Severity'].value_counts()
severities1 = data[data['Severity'] == 1]['Severity'].value_counts()
severity_df = pd.concat([severities4, severities3, severities2, severities1]).reset_index()
severity_df = pd.DataFrame(severity_df)
severity_df = severity_df.rename(columns = {'index':'Severity','Severity':'Counts'})
severity_df
# Out:
#    Severity   Counts
# 0         4    92337
# 1         3   887620
# 2         2  1993410
# 3         1      968

# %%
sns.set(style="white", context="talk")
fig, ax = plt.subplots(figsize=(16,10)) 
sns.barplot(x = severity_df.Severity, y = severity_df.Counts)
plt.xticks(rotation=90)
plt.title('Number of Accidents by Severity 2016 - 2019\n', fontsize = 30)
plt.xlabel('Severity', fontsize = 30)
plt.xticks(fontsize = 20)
plt.ylabel('# of Accidents', fontsize = 30)
# Out:
# Text(0, 0.5, '# of Accidents')

# %% [markdown]
# ### WebScraping

# %%
url = 'https://en.wikipedia.org/wiki/Seat_belt_laws_in_the_United_States'
wiki = requests.get(url).content
wikisoup = BeautifulSoup(wiki, 'html.parser')
my_table = wikisoup.find('table',{'class':'wikitable sortable'})
my_table_info = my_table.findAll('a')
my_table_info
table = []

for value in my_table:
    for i in my_table.findAll('td'):
        table.append(i.text.strip())

seatbelts = pd.DataFrame(table)

# %%
seatbelts
# Out:
#                                      0
# 0                              Alabama
# 1                  Primary Enforcement
# 2                        July 18, 1991
# 3               Age 15+ in front seats
# 4                                  $25
# ..                                 ...
# 679              Secondary Enforcement
# 680                       June 8, 1989
# 681                Age 9+ in all seats
# 682  $25 for driver; $10 for passenger
# 683                              84.8%
#
# [684 rows x 1 columns]

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Seat_belt_laws_in_the_United_States')[0]
df.columns
# Out:
# Index(['State, federal district, or territory', 'Type of law',
#        'Date of first law', 'Who is covered', 'Base fine before fees',
#        'Seat Belt Usage (2017)[7][note 2]'],
#       dtype='object')

# %%
stateabbr = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations')
stateabbr = stateabbr[0]

# %%
df = df.drop(['Type of law','Date of first law','Who is covered','Base fine before fees'], axis = 1)

# %%
df = df.rename(columns = {'State, federal district, or territory':'State','Seat Belt Usage (2017)[7][note 2]':'Seatbelt'})

# %%
df = df.drop(52) ### Wake Island has no data.

# %%
df.sort_values(by = 'Seatbelt', ascending = False).head()
# Out:
#          State Seatbelt
# 11     Georgia    97.1%
# 13      Hawaii    96.9%
# 40      Oregon    96.8%
# 5   California    96.2%
# 53  Washington    94.8%

# %%
sort_grouped.head()
# Out:
#    State  Severity
# 3     CA   1107610
# 41    TX    583689
# 8     FL    456193
# 32    NY    284274
# 38    SC    272430

# %%
r = np.corrcoef(df.Seatbelt)

# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
# #### Hypothesis : The Average Severity of Car Accidents in the USA is above 2.5

# %%
st, p_value =  stats.ttest_1samp(data['Severity'], 2.5)

# %%
st
# Out:
# -445.30320440188416

# %%
p_value
# Out:
# 0.0

# %%
data['Severity'].mean()
# Out:
# 2.360190092911525

# %% [markdown]
# ##### Reject hypothesis : doesn't really work because the variance of the data is very low.

# %% [markdown]
# #### Hypothesis, the average distance that an accident affects the road would be one mile.

# %%
st, p_value =  stats.ttest_1samp(data['Distance(mi)'], 1)

# %%
print(st, p_value)
# Out:
# -795.7497672553656 0.0

# %%
data['Distance(mi)'].mean()
# Out:
# 0.2855653569462776

# %% [markdown]
# ##### Reject hypothesis, average accident distance is less than one mile

# %% [markdown]
# ---------------

# %% [markdown]
# #### Hypothesis: Severities of Four result in accidents that are 1.4 miles long.

# %%
data.loc[data.Severity == 4]['Distance(mi)'].mean()
# Out:
# 1.7015939767430726

# %%
st, p_value =  stats.ttest_1samp(data.loc[data.Severity == 4]['Distance(mi)'], 1.4)

# %%
print(st, p_value)
# Out:
# 24.766460401466276 5.701732427349463e-135

# %% [markdown]
# ##### Hypothesis can be rejected

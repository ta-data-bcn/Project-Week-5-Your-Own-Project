# %%
import pandas as pd
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

df=pd.read_html(url, header=0)[0]

df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
url2 = 'https://vgsales.fandom.com/wiki/PlayStation_3'

df2=pd.read_html(url2, header=0)[1]

df2.head(50)
# Out:
#    PlayStation 3 hardware sales figures (based on official financial reports)[24]  \
# 0                                                Date
# 1                     Quarter 3 (ending Dec 31, 2006)
# 2                     Quarter 4 (ending Mar 31, 2007)
# 3                              2007 fiscal year sales
# 4                     Quarter 1 (ending Jun 30, 2007)
# 5                     Quarter 2 (ending Sep 30, 2007)
# 6                     Quarter 3 (ending Dec 31, 2007)
# 7                     Quarter 4 (ending Mar 31, 2008)
# 8                              2008 fiscal year sales
# 9                     Quarter 1 (ending Jun 30, 2008)
# 10                    Quarter 2 (ending Sep 30, 2008)
# 11                    Quarter 3 (ending Dec 31, 2008)
# 12                    Quarter 4 (ending Mar 31, 2009)
# 13                             2009 fiscal year sales
# 14                    Quarter 1 (ending Jun 30, 2009)
# 15                   Quarter 2 (ending Sept 30, 2009)
# ...

# %%
url_ps2 = 'https://vgsales.fandom.com/wiki/PlayStation_2'

df_ps2=pd.read_html(url_ps2, header=0)[0]

df_ps2.head(50)
# Out:
#    PlayStation 2 sales figures (production shipments) (based on official financial reports[1][2])  \
# 0                                                Date
# 1                   Fiscal year ending March 31, 2000
# 2                   Fiscal year ending March 31, 2001
# 3                   Fiscal year ending March 31, 2002
# 4                   Fiscal year ending March 31, 2003
# 5                   Fiscal year ending March 31, 2004
# 6                   Fiscal year ending March 31, 2005
# 7                   Fiscal year ending March 31, 2006
# 8                   Fiscal year ending March 31, 2007
# 9                   Fiscal year ending March 31, 2008
# 10                  Fiscal year ending March 31, 2009
# 11                  Fiscal year ending March 31, 2010
# 12                  Fiscal year ending March 31, 2011
#
#    PlayStation 2 sales figures (production shipments) (based on official financial reports[1][2]).1  \
# 0                                        Annual sales
# ...

# %%
url_total_consoles = 'http://www.vgchartz.com/analysis/platform_totals/'

df_total_consoles=pd.read_html(url_total_consoles, header=0)[0]

df_total_consoles.head(50)
# Out:
#     Pos                                    Platform  North America  Europe  \
# 0     1                         PlayStation 2 (PS2)          53.65   55.28
# 1     2                            Nintendo DS (DS)          57.39   52.07
# 2     3                               Game Boy (GB)          43.18   40.05
# 3     4                         PlayStation 4 (PS4)          35.55   43.90
# 4     5                            PlayStation (PS)          40.78   31.09
# 5     6                                   Wii (Wii)          45.51   33.88
# 6     7                         PlayStation 3 (PS3)          29.42   34.99
# 7     8                             Xbox 360 (X360)          49.11   25.87
# 8     9                      Game Boy Advance (GBA)          40.39   21.31
# 9    10                  PlayStation Portable (PSP)          21.41   24.41
# 10   11                          Nintendo 3DS (3DS)          25.24   20.95
# ...

# %%
url_trans = 'https://en.wikipedia.org/wiki/Transistor_count'

df_trans=pd.read_html(url_trans, header=1)[0]

df_trans.head(50)
# Out:
#                                MP944 (20-bit, 6-chip)               ?  \
# 0                          Intel 4004 (4-bit, 16-pin)            2250
# 1                          Intel 8008 (8-bit, 18-pin)            3500
# 2                          NEC μCOM-4 (4-bit, 42-pin)   2,500[22][23]
# 3                            Toshiba TLCS-12 (12-bit)     11,000+[25]
# 4                          Intel 4040 (4-bit, 16-pin)            3000
# 5                       Motorola 6800 (8-bit, 40-pin)            4100
# 6                          Intel 8080 (8-bit, 40-pin)            6000
# 7                            TMS 1000 (4-bit, 28-pin)            8000
# 8                 MOS Technology 6502 (8-bit, 40-pin)    4,528[b][27]
# 9    Intersil IM6100 (12-bit, 40-pin; clone of PDP-8)            4000
# 10                   CDP 1801 (8-bit, 2-chip; 40-pin)            5000
# 11                           RCA 1802 (8-bit, 40-pin)            5000
# ...
